# %% [markdown]
#  > #   LAPTOP PRICE PREDICTION

# %% [markdown]
# #### ***This project is made using PANDAS module and SKLEARN***
#
# ---
#
# ### List of all the encoded data:
#
# #### RAM
# ram = {
#   '4 GB'  : 4,
#   '8 GB'  : 8,
#   '16 GB' : 16,
#   '32 GB' : 32
# }
#
# ---
#
# #### Brand
# brand = {
#   'ASUS'   : 1,
#   'Lenovo' : 2,
#   'acer'   : 3,
#   'Avita'  : 4,
#   'HP'     : 5,
#   'DELL'   : 6,
#   'MSI'    : 7,
#   'APPLE'  : 8
# }
#
# ---
#
# #### Processor Company
# processor = {
#   'Intel' : 1,
#   'AMD'   : 2,
#   'M1'    : 3
# }
#
# ---
#
# #### Processor Name
# processor_name = {
#   'Core i3'        : 1,
#   'Core i5'        : 2,
#   'Celeron Dual'   : 3,
#   'Ryzen 5'        : 4,
#   'Core i7'        : 5,
#   'Core i9'        : 6,
#   'M1'             : 7,
#   'Pentium Quad'   : 8,
#   'Ryzen 3'        : 9,
#   'Ryzen 7'        : 10,
#   'Ryzen 9'        : 11
# }
#
# ---
#
# #### Processor Generation
# processor_gnrtn = {
#   'Not Available' : 0,
#   '4th'           : 4,
#   '7th'           : 7,
#   '8th'           : 8,
#   '9th'           : 9,
#   '10th'          : 10,
#   '11th'          : 11,
#   '12th'          : 12
# }
#
# ---
#
# #### RAM Type
# ram_type = {
#   'DDR4'    : 1,
#   'LPDDR4'  : 2,
#   'LPDDR4X' : 3,
#   'DDR5'    : 4,
#   'DDR3'    : 5,
#   'LPDDR3'  : 6
# }
#
# ---
#
# #### SSD Storage
# ssd = {
#   '0 GB'    : 0,
#   '128 GB'  : 128,
#   '256 GB'  : 256,
#   '512 GB'  : 512,
#   '1024 GB' : 1024,
#   '2048 GB' : 2048,
#   '3072 GB' : 3072
# }
#
# ---
#
# #### HDD Storage
# hdd = {
#   '0 GB'    : 0,
#   '512 GB'  : 512,
#   '1024 GB' : 1024,
#   '2048 GB' : 2048
# }
#
# ---
#
# #### Operating System Bit
# os_bit = {
#   '32-bit' : 32,
#   '64-bit' : 64
# }
#
# ---
#
# #### Graphics Card (GB)
# graphic_card_gb = {
#   '0 GB' : 0,
#   '2 GB' : 2,
#   '4 GB' : 4,
#   '6 GB' : 6,
#   '8 GB' : 8
# }
#
# ---
#
# #### Laptop Weight Category
# weight = {
#   'Casual'    : 0,
#   'ThinNlight': 1,
#   'Gaming'    : 2
# }
#
# ---
#
# #### Warranty
# warranty = {
#   'No warranty' : 0,
#   '1 year'      : 1,
#   '2 years'     : 2,
#   '3 years'     : 3
# }
#
# ---
#
# #### Touchscreen
# Touchscreen = {
#   'No'  : 0,
#   'Yes' : 1
# }
#
# ---
#
# #### MS Office
# msoffice = {
#   'No'  : 0,
#   'Yes' : 1
# }
#
# ---
#
# #### Operating System
# os = {
#   'Windows' : 1,
#   'DOS'     : 2,
#   'Mac'     : 3
# }

# %% [markdown]
# ### Loading csv data file

# %%
import pandas as  pd
import numpy as np

# %%
df = pd.read_csv('laptopPrice.csv')

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
# ...

# %% [markdown]
# ### Removing duplicates

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Length: 823, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(21)

# %%
df.drop_duplicates()
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.drop_duplicates(inplace=True) # inplace=True removes duplicates permanently from the original DataFrame

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %% [markdown]
# ### Removing null values if exist

# %%
df.isnull()
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0    False            False           False            False   False
# 1    False            False           False            False   False
# 2    False            False           False            False   False
# 3    False            False           False            False   False
# 4    False            False           False            False   False
# ..     ...              ...             ...              ...     ...
# 818  False            False           False            False   False
# 819  False            False           False            False   False
# 820  False            False           False            False   False
# 821  False            False           False            False   False
# 822  False            False           False            False   False
#
#      ram_type    ssd    hdd     os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df.dropna(inplace=True) #drop null value and place to df and return none

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     802.000000          802.00000         802.000000
# mean    76625.543641          299.84414          36.089776
# std     45232.984422         1001.78442         118.313553
# min     16990.000000            0.00000           0.000000
# 25%     45990.000000            0.00000           0.000000
# 50%     63990.000000           17.00000           2.000000
# 75%     89525.000000          140.25000          18.000000
# max    441990.000000        15279.00000        1947.000000

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %% [markdown]
# ### Dropping unnecessary columns

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.drop(
    ['rating', 'Number of Ratings', 'Number of Reviews'],
    axis=1,
    inplace=True
)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
# ...

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price'],
#       dtype='object')

# %% [markdown]
# ## ❓ Question:
#
# How many AMD laptops are manufactured by Dell that have:
#
# - RAM greater than or equal to 8 GB
# - Price less than ₹60,000
# - With MS Office Support and inbuilt - SSD

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
DELL= df[df['brand']=="DELL"]

# %%
DELL
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 29   DELL           Intel        Core i3            10th   8 GB     DDR4
# 36   DELL           Intel        Core i3            11th   8 GB     DDR4
# 39   DELL           Intel        Core i3            11th   8 GB     DDR4
# 40   DELL           Intel        Core i3            10th   4 GB     DDR4
# 44   DELL           Intel        Core i3            10th   4 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 729  DELL             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 736  DELL             AMD        Ryzen 5   Not Available   4 GB     DDR4
# 746  DELL             AMD        Ryzen 7   Not Available  16 GB     DDR4
# 764  DELL             AMD        Ryzen 7   Not Available   4 GB     DDR4
# 769  DELL             AMD        Ryzen 7   Not Available   4 GB     DDR4
#
#         ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
df['ram_gb'].unique()
# Out:
# array(['4 GB', '8 GB', '16 GB', '32 GB'], dtype=object)

# %%
DELL =DELL[DELL['ram_gb']!='4 GB'] #as less than 8 GB  , only 4 GB exist

# %%
DELL
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 29   DELL           Intel        Core i3            10th   8 GB     DDR4
# 36   DELL           Intel        Core i3            11th   8 GB     DDR4
# 39   DELL           Intel        Core i3            11th   8 GB     DDR4
# 47   DELL           Intel        Core i3            11th   8 GB     DDR4
# 48   DELL           Intel        Core i3            11th   8 GB     DDR4
# ..    ...             ...            ...             ...    ...      ...
# 683  DELL             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 695  DELL             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 696  DELL             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 729  DELL             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 746  DELL             AMD        Ryzen 7   Not Available  16 GB     DDR4
#
#         ssd      hdd       os  os_bit graphic_card_gb      weight  \
# ...

# %%
DELL= DELL[DELL['Price']< 60000]

# %%
DELL
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 29   DELL           Intel        Core i3            10th   8 GB     DDR4
# 36   DELL           Intel        Core i3            11th   8 GB     DDR4
# 39   DELL           Intel        Core i3            11th   8 GB     DDR4
# 47   DELL           Intel        Core i3            11th   8 GB     DDR4
# 48   DELL           Intel        Core i3            11th   8 GB     DDR4
# 49   DELL           Intel        Core i3            11th   8 GB     DDR4
# 50   DELL           Intel        Core i3            11th   8 GB     DDR4
# 82   DELL           Intel        Core i3            11th   8 GB     DDR4
# 95   DELL           Intel        Core i3            11th   8 GB     DDR4
# 110  DELL           Intel        Core i3            10th   8 GB     DDR4
# 111  DELL           Intel        Core i3            10th   8 GB     DDR4
# 128  DELL           Intel        Core i3            11th   8 GB     DDR4
# ...

# %%
DELL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, 29 to 729
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            52 non-null     object
#  1   processor_brand  52 non-null     object
#  2   processor_name   52 non-null     object
#  3   processor_gnrtn  52 non-null     object
#  4   ram_gb           52 non-null     object
#  5   ram_type         52 non-null     object
#  6   ssd              52 non-null     object
#  7   hdd              52 non-null     object
#  8   os               52 non-null     object
#  9   os_bit           52 non-null     object
#  10  graphic_card_gb  52 non-null     object
#  11  weight           52 non-null     object
#  12  warranty         52 non-null     object
#  13  Touchscreen      52 non-null     object
#  14  msoffice         52 non-null     object
#  15  Price            52 non-null     int64
# dtypes: int64(1), object(15)
# ...

# %%
DELL = DELL[DELL['msoffice']=='Yes']

# %%
DELL
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 29   DELL           Intel        Core i3            10th   8 GB     DDR4
# 36   DELL           Intel        Core i3            11th   8 GB     DDR4
# 49   DELL           Intel        Core i3            11th   8 GB     DDR4
# 110  DELL           Intel        Core i3            10th   8 GB     DDR4
# 134  DELL           Intel        Core i3            10th   8 GB     DDR4
# 157  DELL           Intel        Core i3            11th   8 GB     DDR4
# 171  DELL           Intel        Core i3            10th   8 GB     DDR4
# 293  DELL           Intel        Core i5            11th   8 GB     DDR4
# 418  DELL           Intel        Core i5            11th   8 GB     DDR4
# 458  DELL           Intel        Core i5            11th   8 GB     DDR4
# 463  DELL           Intel        Core i5            11th   8 GB     DDR4
# 471  DELL           Intel        Core i5            11th   8 GB     DDR4
# ...

# %%
DELL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 29 to 696
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            18 non-null     object
#  1   processor_brand  18 non-null     object
#  2   processor_name   18 non-null     object
#  3   processor_gnrtn  18 non-null     object
#  4   ram_gb           18 non-null     object
#  5   ram_type         18 non-null     object
#  6   ssd              18 non-null     object
#  7   hdd              18 non-null     object
#  8   os               18 non-null     object
#  9   os_bit           18 non-null     object
#  10  graphic_card_gb  18 non-null     object
#  11  weight           18 non-null     object
#  12  warranty         18 non-null     object
#  13  Touchscreen      18 non-null     object
#  14  msoffice         18 non-null     object
#  15  Price            18 non-null     int64
# dtypes: int64(1), object(15)
# ...

# %%
DELL = DELL[DELL['ssd']!='0 GB']

# %%
DELL
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 29   DELL           Intel        Core i3            10th   8 GB     DDR4
# 36   DELL           Intel        Core i3            11th   8 GB     DDR4
# 49   DELL           Intel        Core i3            11th   8 GB     DDR4
# 110  DELL           Intel        Core i3            10th   8 GB     DDR4
# 171  DELL           Intel        Core i3            10th   8 GB     DDR4
# 293  DELL           Intel        Core i5            11th   8 GB     DDR4
# 458  DELL           Intel        Core i5            11th   8 GB     DDR4
# 463  DELL           Intel        Core i5            11th   8 GB     DDR4
# 471  DELL           Intel        Core i5            11th   8 GB     DDR4
# 662  DELL             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 664  DELL             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 665  DELL             AMD        Ryzen 5   Not Available   8 GB     DDR4
# ...

# %%
DELL = DELL[DELL['processor_brand']=="AMD"]

# %%
DELL
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 662  DELL             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 664  DELL             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 665  DELL             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 695  DELL             AMD        Ryzen 5   Not Available   8 GB     DDR4
# 696  DELL             AMD        Ryzen 5   Not Available   8 GB     DDR4
#
#         ssd   hdd       os  os_bit graphic_card_gb      weight warranty  \
# 662  256 GB  0 GB  Windows  64-bit            0 GB      Casual   1 year
# 664  256 GB  0 GB  Windows  64-bit            0 GB      Casual   1 year
# 665  256 GB  0 GB  Windows  64-bit            0 GB  ThinNlight   1 year
# 695  512 GB  0 GB  Windows  64-bit            0 GB  ThinNlight   1 year
# 696  512 GB  0 GB  Windows  64-bit            0 GB  ThinNlight   1 year
#
#     Touchscreen msoffice  Price
# 662          No      Yes  41990
# ...

# %%
print("Total no. of laptops matching the given condition is ",len(DELL))
# Out:
# Total no. of laptops matching the given condition is  5

# %% [markdown]
# ### Ans : 5 Laptops

# %% [markdown]
# ### Column Encoding
# >must before using in ML models

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 802 entries, 0 to 822
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            802 non-null    object
#  1   processor_brand  802 non-null    object
#  2   processor_name   802 non-null    object
#  3   processor_gnrtn  802 non-null    object
#  4   ram_gb           802 non-null    object
#  5   ram_type         802 non-null    object
#  6   ssd              802 non-null    object
#  7   hdd              802 non-null    object
#  8   os               802 non-null    object
#  9   os_bit           802 non-null    object
#  10  graphic_card_gb  802 non-null    object
#  11  weight           802 non-null    object
#  12  warranty         802 non-null    object
#  13  Touchscreen      802 non-null    object
#  14  msoffice         802 non-null    object
#  15  Price            802 non-null    int64
# dtypes: int64(1), object(15)
# ...

# %%
print(df['ram_gb'].dtype)
# Out:
# object

# %%
df['ram_gb'].unique()
# Out:
# array(['4 GB', '8 GB', '16 GB', '32 GB'], dtype=object)

# %%
df['ram_gb'].nunique()
# Out:
# 4

# %%
ram ={ '4 GB':4,
       '8 GB':8,
       '16 GB':16,
       '32 GB':32,
      }
#converting object to int

# %%
df['ram_gb'] = df['ram_gb'].map(ram)

# %%
print(df['ram_gb'].dtype)
# Out:
# int64

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn  ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th       4     DDR4
# 1    Lenovo           Intel        Core i3            10th       4     DDR4
# 2    Lenovo           Intel        Core i3            10th       4     DDR4
# 3      ASUS           Intel        Core i5            10th       8     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available       4     DDR4
# ..      ...             ...            ...             ...     ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available       4     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available       4     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available       4     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available       4     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th       8     DDR4
#
# ...

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
brand={'ASUS':1, 'Lenovo':2, 'acer':3, 'Avita':4, 'HP':5, 'DELL':6, 'MSI':7, 'APPLE':8}

# %%
df['brand']=df['brand'].map(brand)

# %%
print(df['brand'].dtype)
# Out:
# int64

# %%
df['processor_brand'].unique()
# Out:
# array(['Intel', 'AMD', 'M1'], dtype=object)

# %%
processor={'Intel':1, 'AMD':2, 'M1':3}

# %%
df['processor_brand'] = df['processor_brand'].map(processor)
print(df['processor_brand'].dtype)
# Out:
# int64

# %%
df['processor_name'].unique()
# Out:
# array(['Core i3', 'Core i5', 'Celeron Dual', 'Ryzen 5', 'Core i7',
#        'Core i9', 'M1', 'Pentium Quad', 'Ryzen 3', 'Ryzen 7', 'Ryzen 9'],
#       dtype=object)

# %%
processor_name = {'Core i3':1, 'Core i5':2, 'Celeron Dual':3, 'Ryzen 5':4, 'Core i7':5,
       'Core i9':6, 'M1':7, 'Pentium Quad':8, 'Ryzen 3':9, 'Ryzen 7':10, 'Ryzen 9':11}

# %%
df['processor_name'] = df['processor_name'].map(processor_name)
print(df['processor_name'].dtype)
# Out:
# int64

# %%
df['processor_gnrtn'].unique()
# Out:
# array(['10th', 'Not Available', '11th', '7th', '8th', '9th', '4th',
#        '12th'], dtype=object)

# %%
processor_gnrtn = {'10th':10, 'Not Available':0, '11th':11, '7th':7, '8th':8, '9th':9, '4th':4,
       '12th':12}

# %%
df['processor_gnrtn'] = df['processor_gnrtn'].map(processor_gnrtn)
print(df['processor_gnrtn'].dtype)
# Out:
# int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 802 entries, 0 to 822
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            802 non-null    int64
#  1   processor_brand  802 non-null    int64
#  2   processor_name   802 non-null    int64
#  3   processor_gnrtn  802 non-null    int64
#  4   ram_gb           802 non-null    int64
#  5   ram_type         802 non-null    object
#  6   ssd              802 non-null    object
#  7   hdd              802 non-null    object
#  8   os               802 non-null    object
#  9   os_bit           802 non-null    object
#  10  graphic_card_gb  802 non-null    object
#  11  weight           802 non-null    object
#  12  warranty         802 non-null    object
#  13  Touchscreen      802 non-null    object
#  14  msoffice         802 non-null    object
#  15  Price            802 non-null    int64
# dtypes: int64(6), object(10)
# ...

# %%
df['ram_type'].unique()
# Out:
# array(['DDR4', 'LPDDR4', 'LPDDR4X', 'DDR5', 'DDR3', 'LPDDR3'],
#       dtype=object)

# %%
ram_type = {'DDR4':1, 'LPDDR4':2, 'LPDDR4X':3, 'DDR5':4, 'DDR3':5, 'LPDDR3':6}

# %%
df['ram_type'] = df['ram_type'].map(ram_type)
print(df['ram_type'].dtype)
# Out:
# int64

# %%
df['ssd'].unique()
# Out:
# array(['0 GB', '512 GB', '256 GB', '128 GB', '1024 GB', '2048 GB',
#        '3072 GB'], dtype=object)

# %%
ssd = {'0 GB':0, '512 GB':512, '256 GB':256, '128 GB':128, '1024 GB':1024, '2048 GB':2048,
       '3072 GB':3072}

# %%
df['ssd'] = df['ssd'].map(ssd)
print(df['ssd'].dtype)
# Out:
# int64

# %%
df['hdd'].unique()
# Out:
# array(['1024 GB', '0 GB', '512 GB', '2048 GB'], dtype=object)

# %%
hdd = {'1024 GB':1024, '0 GB':0, '512 GB':512, '2048 GB':2048}

# %%
df['hdd'] = df['hdd'].map(hdd)
print(df['hdd'].dtype)
# Out:
# int64

# %%
df['os'].unique()
# Out:
# array(['Windows', 'DOS', 'Mac'], dtype=object)

# %%
df['os_bit'].unique()
# Out:
# array(['64-bit', '32-bit'], dtype=object)

# %%
os_bit={'64-bit':64, '32-bit':32}

# %%
df['os_bit'] = df['os_bit'].map(os_bit)
print(df['os_bit'].dtype)
# Out:
# int64

# %%
df['graphic_card_gb'].unique()
# Out:
# array(['0 GB', '2 GB', '4 GB', '6 GB', '8 GB'], dtype=object)

# %%
graphic_card_gb={'0 GB':0, '2 GB':2, '4 GB':4, '6 GB':6, '8 GB':8}

# %%
df['graphic_card_gb'] = df['graphic_card_gb'].map(graphic_card_gb)
print(df['graphic_card_gb'].dtype)
# Out:
# int64

# %%
df['weight'].unique()
# Out:
# array(['Casual', 'ThinNlight', 'Gaming'], dtype=object)

# %%
weight={'Casual':0, 'ThinNlight':1, 'Gaming':2}

# %%
df['weight'] = df['weight'].map(weight)
print(df['weight'].dtype)
# Out:
# int64

# %%
df['warranty'].unique()
# Out:
# array(['No warranty', '1 year', '2 years', '3 years'], dtype=object)

# %%
warranty={'No warranty':0, '1 year':1, '2 years':2, '3 years':3}

# %%
df['warranty'] = df['warranty'].map(warranty)
print(df['warranty'].dtype)
# Out:
# int64

# %%
df['Touchscreen'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
Touchscreen ={'No':0, 'Yes':1}

# %%
df['Touchscreen'] = df['Touchscreen'].map(Touchscreen)
print(df['Touchscreen'].dtype)
# Out:
# int64

# %%
df['msoffice'].unique()
# Out:
# array(['No', 'Yes'], dtype=object)

# %%
msoffice={'No':0, 'Yes':1}

# %%
df['msoffice'] = df['msoffice'].map(msoffice)
print(df['msoffice'].dtype)
# Out:
# int64

# %%
os={'Windows':1, 'DOS':2, 'Mac':3}

# %%
df['os'] = df['os'].map(os)
print(df['os'].dtype)
# Out:
# int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 802 entries, 0 to 822
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            802 non-null    int64
#  1   processor_brand  802 non-null    int64
#  2   processor_name   802 non-null    int64
#  3   processor_gnrtn  802 non-null    int64
#  4   ram_gb           802 non-null    int64
#  5   ram_type         802 non-null    int64
#  6   ssd              802 non-null    int64
#  7   hdd              802 non-null    int64
#  8   os               802 non-null    int64
#  9   os_bit           802 non-null    int64
#  10  graphic_card_gb  802 non-null    int64
#  11  weight           802 non-null    int64
#  12  warranty         802 non-null    int64
#  13  Touchscreen      802 non-null    int64
#  14  msoffice         802 non-null    int64
#  15  Price            802 non-null    int64
# dtypes: int64(16)
# memory usage: 106.5 KB

# %%
df
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1               10       4
# 1        2                1               1               10       4
# 2        2                1               1               10       4
# 3        1                1               2               10       8
# 4        1                1               3                0       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                0       4
# 819      1                2              11                0       4
# 820      1                2              11                0       4
# 821      1                2              11                0       4
# 822      2                2               4               10       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %% [markdown]
# ### Encoding successfull

# %% [markdown]
# ### Making new updated csv file after encoding

# %%
df.to_csv('updated_laptopPrice_csv')

# %% [markdown]
# > Now divide data into two parts (dependent and independent variables)

# %%
x=df.drop('Price',axis=1) #independent variables, after dropping eveything except price and storing in x variable

# %%
y= df[['Price']] #dependent variable (price left in df)

# %%
x
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0        1                1               1               10       4
# 1        2                1               1               10       4
# 2        2                1               1               10       4
# 3        1                1               2               10       8
# 4        1                1               3                0       4
# ..     ...              ...             ...              ...     ...
# 818      1                2              11                0       4
# 819      1                2              11                0       4
# 820      1                2              11                0       4
# 821      1                2              11                0       4
# 822      2                2               4               10       8
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
y
# Out:
#       Price
# 0     34649
# 1     38999
# 2     39999
# 3     69990
# 4     26990
# ..      ...
# 818  135990
# 819  144990
# 820  149990
# 821  142990
# 822   57490
#
# [802 rows x 1 columns]

# %% [markdown]
# > ### DATA SPLITTING

# %%
import sklearn as sns

# %%
from sklearn.linear_model import LinearRegression
#create a regression model for prediction

from sklearn.model_selection import train_test_split
#divide data into training and testing sets

x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)
#20 %data is for testing data , 42 ensures same rows are selected together each time

# %%
x_train
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 442      1                1               2               11       8
# 598      1                1               5               10      16
# 452      1                1               2               11       8
# 696      6                2               4                0       8
# 339      1                1               2               11       8
# ..     ...              ...             ...              ...     ...
# 73       2                1               1               10       4
# 108      6                1               1               11       8
# 275      2                1               2               10       8
# 445      1                1               2               11       8
# 104      1                1               1               11       8
#
#      ram_type  ssd   hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
y_train
# Out:
#       Price
# 442   50990
# 598  146490
# 452   60190
# 696   59490
# 339   99990
# ..      ...
# 73    41990
# 108   60790
# 275   57500
# 445   52990
# 104   44990
#
# [641 rows x 1 columns]

# %%
x_test
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 196      3                1               2                0       8
# 299      1                1               2               11       8
# 171      6                1               1               10       8
# 537      5                1               5               10      16
# 551      7                1               5               11      16
# ..     ...              ...             ...              ...     ...
# 368      1                1               2               11       8
# 361      5                1               2               10       8
# 446      6                1               2               11       8
# 767      2                2              10                0       4
# 529      2                1               5               11      16
#
#      ram_type   ssd   hdd  os  os_bit  graphic_card_gb  weight  warranty  \
# ...

# %%
y_test
# Out:
#       Price
# 196   50990
# 299   72990
# 171   41490
# 537  144690
# 551  129990
# ..      ...
# 368  114990
# 361  126000
# 446   57990
# 767  106990
# 529  110999
#
# [161 rows x 1 columns]

# %%
x_train.shape , y_train.shape , x_test.shape, y_test.shape #rows & columns
# Out:
# ((641, 15), (641, 1), (161, 15), (161, 1))

# %% [markdown]
# > ### CREATION OF MODEL(LINEAR REGRESSION)

# %%
lr=LinearRegression() #creation of object

# %%
lr.fit(x_train, y_train) #teaches the model using known data so it can predict prices for new dat
# Out:
# LinearRegression()

# %%
pred=lr.predict(x_test) #actual result is in y test

# %%
print(y_test,pred) #y_test is a Pandas Series whereas pred is a NumPy array(only values)
# Out:
#       Price
# 196   50990
# 299   72990
# 171   41490
# 537  144690
# 551  129990
# ..      ...
# 368  114990
# 361  126000
# 446   57990
# 767  106990
# 529  110999
#
# [161 rows x 1 columns] [[ 76155.44979736]
#  [ 81022.51609067]
#  [ 54998.33649988]
#  [147076.35975698]
#  [166318.90935701]
#  [150589.69956371]
#  [139118.84649202]
#  [ 90337.95178524]
#  [ 58413.63108302]
#  [ 93147.5580916 ]
#  [ 39551.72463961]
#  [ 42188.41170081]
#  [ 75367.59545045]
#  [ 99844.24439842]
#  [ 57727.61041683]
#  [116570.04907506]
#  [ 78717.04851525]
#  [ 60201.25413767]
#  [ 63485.94719425]
#  [165987.70976276]
#  [ 41812.59659412]
#  [ 31041.86600489]
#  [ 69457.0921272 ]
#  [ 46403.59246471]
#  [ 30205.09865849]
#  [ 40466.47648786]
#  [ 76520.66811131]
#  [154872.0625424 ]
#  [ 40652.88882105]
#  [ 30194.97054008]
#  [ 61995.73261016]
#  [ 56578.94511214]
#  [ 60350.63244732]
#  [ 58680.31063859]
#  [ 55137.09942593]
#  [ 29462.84373877]
#  [175744.78134548]
#  [ 76060.67831261]
# ...

# %%
comparison = pd.DataFrame({
    "Actual Price": y_test.squeeze().values,
    "Predicted Price": pred.squeeze() #converts 2D data (one column) into 1D data.
})

comparison.head(20) #preview the first few rows(20) of a DataFrame to verify the data.
# Out:
#     Actual Price  Predicted Price
# 0          50990     76155.449797
# 1          72990     81022.516091
# 2          41490     54998.336500
# 3         144690    147076.359757
# 4         129990    166318.909357
# 5         142990    150589.699564
# 6         104990    139118.846492
# 7          64990     90337.951785
# 8          51990     58413.631083
# 9         125394     93147.558092
# 10         41990     39551.724640
# 11         32917     42188.411701
# 12         65990     75367.595450
# 13        144990     99844.244398
# 14         57999     57727.610417
# 15        291190    116570.049075
# 16        106490     78717.048515
# 17         45490     60201.254138
# 18         61290     63485.947194
# 19        154990    165987.709763

# %%
lr.score(x_train,y_train) #gives R²,not accuracy
#The model explains about 70% of the price pattern in training data.
# Out:
# 0.7265738662977548

# %%
lr.score(x_test,y_test) 
#The model explains about 75% of the price pattern in unseen (test) data.
# Out:
# 0.6516663175724384

# %%
import joblib #joblib used to save machine learning models
joblib.dump(lr,"modelLr.lb") #lr is object and model.lb is model name
# Out:
# ['modelLr.lb']

# %%
model=joblib.load('modelLr.lb')

# %%
model #Make predictions directly (no training needed)
# Out:
# LinearRegression()

# %%
model.predict(x_test)
# Out:
# array([[ 76155.44979736],
#        [ 81022.51609067],
#        [ 54998.33649988],
#        [147076.35975698],
#        [166318.90935701],
#        [150589.69956371],
#        [139118.84649202],
#        [ 90337.95178524],
#        [ 58413.63108302],
#        [ 93147.5580916 ],
#        [ 39551.72463961],
#        [ 42188.41170081],
#        [ 75367.59545045],
#        [ 99844.24439842],
#        [ 57727.61041683],
#        [116570.04907506],
#        [ 78717.04851525],
#        [ 60201.25413767],
#        [ 63485.94719425],
#        [165987.70976276],
#        [ 41812.59659412],
#        [ 31041.86600489],
#        [ 69457.0921272 ],
#        [ 46403.59246471],
#        [ 30205.09865849],
#        [ 40466.47648786],
#        [ 76520.66811131],
#        [154872.0625424 ],
#        [ 40652.88882105],
#        [ 30194.97054008],
#        [ 61995.73261016],
#        [ 56578.94511214],
#        [ 60350.63244732],
#        [ 58680.31063859],
#        [ 55137.09942593],
# ...

# %%
model.score(x_test, y_test)
# Out:
# 0.6516663175724384

# %%
model.predict([[1,1,1,10,4,1,0,1024,1,64,0,0,0,0,0]]) #data from frontend, #prices removed , data from encoded csv file (updated_used_bike)
#brand,processor_brand,processor_name,processor_gnrtn,ram_gb,ram_type,ssd,hdd,os,os_bit,graphic_card_gb,weight,warranty,Touchscreen,msoffice
# Out:
# c:\Users\isron\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:2691: UserWarning: X does not have valid feature names, but LinearRegression was fitted with feature names
#   warnings.warn(
# array([[29394.43937776]])

# %% [markdown]
# > ### SVM ALGORITHM (SVR)

# %%
from sklearn.svm import SVR

# %%
svm =SVR()
svm.fit(x_train,y_train) #trained with data
# Out:
# c:\Users\isron\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\utils\validation.py:1352: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# SVR()

# %%
import joblib #joblib used to save machine learning models
joblib.dump(svm,"modelsvm.lb")
# Out:
# ['modelsvm.lb']

# %%
print(svm.score(x_train,y_train))
print(svm.score(x_test,y_test))
# Out:
# -0.06437994309103767
# -0.12997040990728115

# %%
svm.predict(x_test) #predicts output values for the test data.
# Out:
# array([64006.07798366, 64115.90043516, 63990.09287313, 64162.41293274,
#        64162.40728082, 64162.38107532, 64115.99760557, 64115.99109424,
#        64115.99146531, 64065.51036234, 64073.70524173, 63978.77256349,
#        64116.01077839, 64162.3780021 , 64115.97181255, 64006.08410339,
#        64115.99674122, 64115.98995421, 64115.99217005, 64162.41038461,
#        63978.84797382, 64073.72999006, 64115.99475922, 64073.73948683,
#        64073.73099252, 64073.74292261, 64115.99600437, 64162.41077962,
#        64073.74138778, 64073.73059998, 63990.09305747, 64115.99114412,
#        63990.09376249, 64115.99147697, 64115.87505812, 64073.73019777,
#        64162.39990309, 64115.90310832, 64073.73211135, 64116.00115498,
#        64073.7299623 , 64115.98562761, 64115.98155149, 63978.76118276,
#        64115.98286752, 64073.74399946, 64162.41070612, 64115.97155556,
#        64162.39896404, 63990.12141532, 64116.01551606, 64006.08836896,
# ...
