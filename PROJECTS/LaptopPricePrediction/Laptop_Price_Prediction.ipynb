# %% [markdown]
#  > #   LAPTOP PRICE PREDICTION

# %% [markdown]
#  #### ***This project is made using PANDAS module***

# %% [markdown]
# ### Loading csv data file

# %%
import pandas as  pd
import numpy as np

# %%
df = pd.read_csv('laptopPrice.csv')

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 0       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 1       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 2       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 3     512 GB     0 GB  Windows  32-bit            2 GB      Casual
# 4       0 GB   512 GB  Windows  64-bit            0 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 818  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 819  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 820  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 821  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 822   512 GB     0 GB      DOS  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   Price   rating  Number of Ratings  \
# 0    No warranty          No       No   34649  2 stars                  3
# 1    No warranty          No       No   38999  3 stars                 65
# 2    No warranty          No       No   39999  3 stars                  8
# 3    No warranty          No       No   69990  3 stars                  0
# 4    No warranty          No       No   26990  3 stars                  0
# ..           ...         ...      ...     ...      ...                ...
# 818       1 year          No       No  135990  3 stars                  0
# 819       1 year          No       No  144990  3 stars                  0
# 820       1 year          No       No  149990  3 stars                  0
# 821       1 year          No       No  142990  3 stars                  0
# 822  No warranty          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [823 rows x 19 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 823 entries, 0 to 822
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   brand              823 non-null    object
#  1   processor_brand    823 non-null    object
#  2   processor_name     823 non-null    object
#  3   processor_gnrtn    823 non-null    object
#  4   ram_gb             823 non-null    object
#  5   ram_type           823 non-null    object
#  6   ssd                823 non-null    object
#  7   hdd                823 non-null    object
#  8   os                 823 non-null    object
#  9   os_bit             823 non-null    object
#  10  graphic_card_gb    823 non-null    object
#  11  weight             823 non-null    object
#  12  warranty           823 non-null    object
#  13  Touchscreen        823 non-null    object
#  14  msoffice           823 non-null    object
#  15  Price              823 non-null    int64
#  16  rating             823 non-null    object
#  17  Number of Ratings  823 non-null    int64
#  18  Number of Reviews  823 non-null    int64
# dtypes: int64(3), object(16)
# memory usage: 122.3+ KB

# %% [markdown]
# ### Removing duplicates

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 818    False
# 819    False
# 820    False
# 821    False
# 822    False
# Length: 823, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(21)

# %%
df.drop_duplicates()
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 0       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 1       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 2       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 3     512 GB     0 GB  Windows  32-bit            2 GB      Casual
# 4       0 GB   512 GB  Windows  64-bit            0 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 818  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 819  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 820  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 821  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 822   512 GB     0 GB      DOS  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   Price   rating  Number of Ratings  \
# 0    No warranty          No       No   34649  2 stars                  3
# 1    No warranty          No       No   38999  3 stars                 65
# 2    No warranty          No       No   39999  3 stars                  8
# 3    No warranty          No       No   69990  3 stars                  0
# 4    No warranty          No       No   26990  3 stars                  0
# ..           ...         ...      ...     ...      ...                ...
# 818       1 year          No       No  135990  3 stars                  0
# 819       1 year          No       No  144990  3 stars                  0
# 820       1 year          No       No  149990  3 stars                  0
# 821       1 year          No       No  142990  3 stars                  0
# 822  No warranty          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [802 rows x 19 columns]

# %%
df.drop_duplicates(inplace=True) # inplace=True removes duplicates permanently from the original DataFrame

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 0       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 1       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 2       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 3     512 GB     0 GB  Windows  32-bit            2 GB      Casual
# 4       0 GB   512 GB  Windows  64-bit            0 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 818  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 819  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 820  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 821  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 822   512 GB     0 GB      DOS  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   Price   rating  Number of Ratings  \
# 0    No warranty          No       No   34649  2 stars                  3
# 1    No warranty          No       No   38999  3 stars                 65
# 2    No warranty          No       No   39999  3 stars                  8
# 3    No warranty          No       No   69990  3 stars                  0
# 4    No warranty          No       No   26990  3 stars                  0
# ..           ...         ...      ...     ...      ...                ...
# 818       1 year          No       No  135990  3 stars                  0
# 819       1 year          No       No  144990  3 stars                  0
# 820       1 year          No       No  149990  3 stars                  0
# 821       1 year          No       No  142990  3 stars                  0
# 822  No warranty          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [802 rows x 19 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 0       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 1       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 2       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 3     512 GB     0 GB  Windows  32-bit            2 GB      Casual
# 4       0 GB   512 GB  Windows  64-bit            0 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 818  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 819  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 820  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 821  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 822   512 GB     0 GB      DOS  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   Price   rating  Number of Ratings  \
# 0    No warranty          No       No   34649  2 stars                  3
# 1    No warranty          No       No   38999  3 stars                 65
# 2    No warranty          No       No   39999  3 stars                  8
# 3    No warranty          No       No   69990  3 stars                  0
# 4    No warranty          No       No   26990  3 stars                  0
# ..           ...         ...      ...     ...      ...                ...
# 818       1 year          No       No  135990  3 stars                  0
# 819       1 year          No       No  144990  3 stars                  0
# 820       1 year          No       No  149990  3 stars                  0
# 821       1 year          No       No  142990  3 stars                  0
# 822  No warranty          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [802 rows x 19 columns]

# %% [markdown]
# ### Removing null values if exist

# %%
df.isnull()
# Out:
#      brand  processor_brand  processor_name  processor_gnrtn  ram_gb  \
# 0    False            False           False            False   False
# 1    False            False           False            False   False
# 2    False            False           False            False   False
# 3    False            False           False            False   False
# 4    False            False           False            False   False
# ..     ...              ...             ...              ...     ...
# 818  False            False           False            False   False
# 819  False            False           False            False   False
# 820  False            False           False            False   False
# 821  False            False           False            False   False
# 822  False            False           False            False   False
#
#      ram_type    ssd    hdd     os  os_bit  graphic_card_gb  weight  warranty  \
# 0       False  False  False  False   False            False   False     False
# 1       False  False  False  False   False            False   False     False
# 2       False  False  False  False   False            False   False     False
# 3       False  False  False  False   False            False   False     False
# 4       False  False  False  False   False            False   False     False
# ..        ...    ...    ...    ...     ...              ...     ...       ...
# 818     False  False  False  False   False            False   False     False
# 819     False  False  False  False   False            False   False     False
# 820     False  False  False  False   False            False   False     False
# 821     False  False  False  False   False            False   False     False
# 822     False  False  False  False   False            False   False     False
#
#      Touchscreen  msoffice  Price  rating  Number of Ratings  \
# 0          False     False  False   False              False
# 1          False     False  False   False              False
# 2          False     False  False   False              False
# 3          False     False  False   False              False
# 4          False     False  False   False              False
# ..           ...       ...    ...     ...                ...
# 818        False     False  False   False              False
# 819        False     False  False   False              False
# 820        False     False  False   False              False
# 821        False     False  False   False              False
# 822        False     False  False   False              False
#
#      Number of Reviews
# 0                False
# 1                False
# 2                False
# 3                False
# 4                False
# ..                 ...
# 818              False
# 819              False
# 820              False
# 821              False
# 822              False
#
# [802 rows x 19 columns]

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df.dropna(inplace=True) #drop null value and place to df and return none

# %%
df.isnull().sum()
# Out:
# brand                0
# processor_brand      0
# processor_name       0
# processor_gnrtn      0
# ram_gb               0
# ram_type             0
# ssd                  0
# hdd                  0
# os                   0
# os_bit               0
# graphic_card_gb      0
# weight               0
# warranty             0
# Touchscreen          0
# msoffice             0
# Price                0
# rating               0
# Number of Ratings    0
# Number of Reviews    0
# dtype: int64

# %%
df.describe()
# Out:
#                Price  Number of Ratings  Number of Reviews
# count     802.000000          802.00000         802.000000
# mean    76625.543641          299.84414          36.089776
# std     45232.984422         1001.78442         118.313553
# min     16990.000000            0.00000           0.000000
# 25%     45990.000000            0.00000           0.000000
# 50%     63990.000000           17.00000           2.000000
# 75%     89525.000000          140.25000          18.000000
# max    441990.000000        15279.00000        1947.000000

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 0       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 1       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 2       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 3     512 GB     0 GB  Windows  32-bit            2 GB      Casual
# 4       0 GB   512 GB  Windows  64-bit            0 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 818  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 819  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 820  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 821  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 822   512 GB     0 GB      DOS  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   Price   rating  Number of Ratings  \
# 0    No warranty          No       No   34649  2 stars                  3
# 1    No warranty          No       No   38999  3 stars                 65
# 2    No warranty          No       No   39999  3 stars                  8
# 3    No warranty          No       No   69990  3 stars                  0
# 4    No warranty          No       No   26990  3 stars                  0
# ..           ...         ...      ...     ...      ...                ...
# 818       1 year          No       No  135990  3 stars                  0
# 819       1 year          No       No  144990  3 stars                  0
# 820       1 year          No       No  149990  3 stars                  0
# 821       1 year          No       No  142990  3 stars                  0
# 822  No warranty          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [802 rows x 19 columns]

# %% [markdown]
# ### Dropping unnecessary columns

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ram_type', 'ssd', 'hdd', 'os', 'os_bit', 'graphic_card_gb',
#        'weight', 'warranty', 'Touchscreen', 'msoffice', 'Price', 'rating',
#        'Number of Ratings', 'Number of Reviews'],
#       dtype='object')

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb ram_type  \
# 0      ASUS           Intel        Core i3            10th   4 GB     DDR4
# 1    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 2    Lenovo           Intel        Core i3            10th   4 GB     DDR4
# 3      ASUS           Intel        Core i5            10th   8 GB     DDR4
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     DDR4
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB     DDR4
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB     DDR4
#
#          ssd      hdd       os  os_bit graphic_card_gb      weight  \
# 0       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 1       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 2       0 GB  1024 GB  Windows  64-bit            0 GB      Casual
# 3     512 GB     0 GB  Windows  32-bit            2 GB      Casual
# 4       0 GB   512 GB  Windows  64-bit            0 GB      Casual
# ..       ...      ...      ...     ...             ...         ...
# 818  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 819  1024 GB     0 GB  Windows  64-bit            0 GB      Casual
# 820  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 821  1024 GB     0 GB  Windows  64-bit            4 GB      Casual
# 822   512 GB     0 GB      DOS  64-bit            0 GB  ThinNlight
#
#         warranty Touchscreen msoffice   Price   rating  Number of Ratings  \
# 0    No warranty          No       No   34649  2 stars                  3
# 1    No warranty          No       No   38999  3 stars                 65
# 2    No warranty          No       No   39999  3 stars                  8
# 3    No warranty          No       No   69990  3 stars                  0
# 4    No warranty          No       No   26990  3 stars                  0
# ..           ...         ...      ...     ...      ...                ...
# 818       1 year          No       No  135990  3 stars                  0
# 819       1 year          No       No  144990  3 stars                  0
# 820       1 year          No       No  149990  3 stars                  0
# 821       1 year          No       No  142990  3 stars                  0
# 822  No warranty          No       No   57490  4 stars                 18
#
#      Number of Reviews
# 0                    0
# 1                    5
# 2                    1
# 3                    0
# 4                    0
# ..                 ...
# 818                  0
# 819                  0
# 820                  0
# 821                  0
# 822                  4
#
# [802 rows x 19 columns]

# %%
df.drop(
    ['ram_type', 'os', 'rating', 'Number of Ratings', 'Number of Reviews'],
    axis=1,
    inplace=True
)

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn ram_gb      ssd  \
# 0      ASUS           Intel        Core i3            10th   4 GB     0 GB
# 1    Lenovo           Intel        Core i3            10th   4 GB     0 GB
# 2    Lenovo           Intel        Core i3            10th   4 GB     0 GB
# 3      ASUS           Intel        Core i5            10th   8 GB   512 GB
# 4      ASUS           Intel   Celeron Dual   Not Available   4 GB     0 GB
# ..      ...             ...            ...             ...    ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available   4 GB  1024 GB
# 819    ASUS             AMD        Ryzen 9   Not Available   4 GB  1024 GB
# 820    ASUS             AMD        Ryzen 9   Not Available   4 GB  1024 GB
# 821    ASUS             AMD        Ryzen 9   Not Available   4 GB  1024 GB
# 822  Lenovo             AMD        Ryzen 5            10th   8 GB   512 GB
#
#          hdd  os_bit graphic_card_gb      weight     warranty Touchscreen  \
# 0    1024 GB  64-bit            0 GB      Casual  No warranty          No
# 1    1024 GB  64-bit            0 GB      Casual  No warranty          No
# 2    1024 GB  64-bit            0 GB      Casual  No warranty          No
# 3       0 GB  32-bit            2 GB      Casual  No warranty          No
# 4     512 GB  64-bit            0 GB      Casual  No warranty          No
# ..       ...     ...             ...         ...          ...         ...
# 818     0 GB  64-bit            0 GB      Casual       1 year          No
# 819     0 GB  64-bit            0 GB      Casual       1 year          No
# 820     0 GB  64-bit            4 GB      Casual       1 year          No
# 821     0 GB  64-bit            4 GB      Casual       1 year          No
# 822     0 GB  64-bit            0 GB  ThinNlight  No warranty          No
#
#     msoffice   Price
# 0         No   34649
# 1         No   38999
# 2         No   39999
# 3         No   69990
# 4         No   26990
# ..       ...     ...
# 818       No  135990
# 819       No  144990
# 820       No  149990
# 821       No  142990
# 822       No   57490
#
# [802 rows x 14 columns]

# %%
df.columns
# Out:
# Index(['brand', 'processor_brand', 'processor_name', 'processor_gnrtn',
#        'ram_gb', 'ssd', 'hdd', 'os_bit', 'graphic_card_gb', 'weight',
#        'warranty', 'Touchscreen', 'msoffice', 'Price'],
#       dtype='object')

# %% [markdown]
# ## ❓ Question:
#
# How many AMD laptops are manufactured by Dell that have:
#
# - RAM greater than or equal to 8 GB
# - Price less than ₹60,000
# - With MS Office Support and inbuilt - SSD

# %%
df['brand'].unique()
# Out:
# array(['ASUS', 'Lenovo', 'acer', 'Avita', 'HP', 'DELL', 'MSI', 'APPLE'],
#       dtype=object)

# %%
DELL= df[df['brand']=="DELL"]

# %%
DELL
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb     ssd  \
# 29   DELL           Intel        Core i3            10th   8 GB  256 GB
# 36   DELL           Intel        Core i3            11th   8 GB  256 GB
# 39   DELL           Intel        Core i3            11th   8 GB  256 GB
# 40   DELL           Intel        Core i3            10th   4 GB  256 GB
# 44   DELL           Intel        Core i3            10th   4 GB  256 GB
# ..    ...             ...            ...             ...    ...     ...
# 729  DELL             AMD        Ryzen 5   Not Available   8 GB  256 GB
# 736  DELL             AMD        Ryzen 5   Not Available   4 GB  256 GB
# 746  DELL             AMD        Ryzen 7   Not Available  16 GB  512 GB
# 764  DELL             AMD        Ryzen 7   Not Available   4 GB  512 GB
# 769  DELL             AMD        Ryzen 7   Not Available   4 GB  512 GB
#
#          hdd  os_bit graphic_card_gb      weight     warranty Touchscreen  \
# 29      0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 36      0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 39      0 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 40      0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 44      0 GB  64-bit            0 GB      Casual       1 year          No
# ..       ...     ...             ...         ...          ...         ...
# 729  1024 GB  64-bit            0 GB      Casual  No warranty          No
# 736  1024 GB  32-bit            0 GB      Casual  No warranty          No
# 746     0 GB  64-bit            4 GB      Casual       1 year          No
# 764     0 GB  64-bit            6 GB      Casual  No warranty          No
# 769     0 GB  64-bit            0 GB      Casual       1 year         Yes
#
#     msoffice  Price
# 29       Yes  39490
# 36       Yes  41990
# 39        No  42490
# 40       Yes  36990
# 44       Yes  39490
# ..       ...    ...
# 729       No  49490
# 736       No  51990
# 746       No  93990
# 764       No  89990
# 769      Yes  89570
#
# [149 rows x 14 columns]

# %%
df['ram_gb'].unique()
# Out:
# array(['4 GB', '8 GB', '16 GB', '32 GB'], dtype=object)

# %%
DELL =DELL[DELL['ram_gb']!='4 GB'] #as less than 8 GB  , only 4 GB exist

# %%
DELL
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb     ssd  \
# 29   DELL           Intel        Core i3            10th   8 GB  256 GB
# 36   DELL           Intel        Core i3            11th   8 GB  256 GB
# 39   DELL           Intel        Core i3            11th   8 GB  256 GB
# 47   DELL           Intel        Core i3            11th   8 GB  256 GB
# 48   DELL           Intel        Core i3            11th   8 GB  256 GB
# ..    ...             ...            ...             ...    ...     ...
# 683  DELL             AMD        Ryzen 5   Not Available   8 GB  512 GB
# 695  DELL             AMD        Ryzen 5   Not Available   8 GB  512 GB
# 696  DELL             AMD        Ryzen 5   Not Available   8 GB  512 GB
# 729  DELL             AMD        Ryzen 5   Not Available   8 GB  256 GB
# 746  DELL             AMD        Ryzen 7   Not Available  16 GB  512 GB
#
#          hdd  os_bit graphic_card_gb      weight     warranty Touchscreen  \
# 29      0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 36      0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 39      0 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 47      0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 48      0 GB  64-bit            0 GB      Casual       1 year         Yes
# ..       ...     ...             ...         ...          ...         ...
# 683     0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 695     0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 696     0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 729  1024 GB  64-bit            0 GB      Casual  No warranty          No
# 746     0 GB  64-bit            4 GB      Casual       1 year          No
#
#     msoffice  Price
# 29       Yes  39490
# 36       Yes  41990
# 39        No  42490
# 47        No  42990
# 48        No  49990
# ..       ...    ...
# 683       No  59490
# 695      Yes  49990
# 696      Yes  59490
# 729       No  49490
# 746       No  93990
#
# [111 rows x 14 columns]

# %%
DELL= DELL[DELL['Price']< 60000]

# %%
DELL
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb     ssd  \
# 29   DELL           Intel        Core i3            10th   8 GB  256 GB
# 36   DELL           Intel        Core i3            11th   8 GB  256 GB
# 39   DELL           Intel        Core i3            11th   8 GB  256 GB
# 47   DELL           Intel        Core i3            11th   8 GB  256 GB
# 48   DELL           Intel        Core i3            11th   8 GB  256 GB
# 49   DELL           Intel        Core i3            11th   8 GB  256 GB
# 50   DELL           Intel        Core i3            11th   8 GB  256 GB
# 82   DELL           Intel        Core i3            11th   8 GB  256 GB
# 95   DELL           Intel        Core i3            11th   8 GB  512 GB
# 110  DELL           Intel        Core i3            10th   8 GB  512 GB
# 111  DELL           Intel        Core i3            10th   8 GB  512 GB
# 128  DELL           Intel        Core i3            11th   8 GB  512 GB
# 132  DELL           Intel        Core i3            11th   8 GB    0 GB
# 133  DELL           Intel        Core i3            11th   8 GB    0 GB
# 134  DELL           Intel        Core i3            10th   8 GB    0 GB
# 137  DELL           Intel        Core i3            11th   8 GB    0 GB
# 157  DELL           Intel        Core i3            11th   8 GB    0 GB
# 162  DELL           Intel        Core i3            11th   8 GB    0 GB
# 164  DELL           Intel        Core i3            11th   8 GB    0 GB
# 168  DELL           Intel        Core i3            10th   8 GB    0 GB
# 171  DELL           Intel        Core i3            10th   8 GB  256 GB
# 172  DELL           Intel        Core i3            11th   8 GB  256 GB
# 173  DELL           Intel        Core i3            11th   8 GB  256 GB
# 177  DELL           Intel        Core i3            11th   8 GB  256 GB
# 187  DELL           Intel        Core i3            10th   8 GB  256 GB
# 209  DELL           Intel        Core i5            11th   8 GB  256 GB
# 293  DELL           Intel        Core i5            11th   8 GB  512 GB
# 296  DELL           Intel        Core i5            11th   8 GB  512 GB
# 418  DELL           Intel        Core i5            11th   8 GB    0 GB
# 426  DELL           Intel        Core i5            11th   8 GB    0 GB
# 431  DELL           Intel        Core i5            11th   8 GB    0 GB
# 446  DELL           Intel        Core i5            11th   8 GB  256 GB
# 458  DELL           Intel        Core i5            11th   8 GB  256 GB
# 463  DELL           Intel        Core i5            11th   8 GB  256 GB
# 471  DELL           Intel        Core i5            11th   8 GB  256 GB
# 638  DELL             AMD        Ryzen 3   Not Available   8 GB  256 GB
# 639  DELL             AMD        Ryzen 3   Not Available   8 GB  256 GB
# 640  DELL             AMD        Ryzen 3   Not Available   8 GB  256 GB
# 642  DELL             AMD        Ryzen 3   Not Available   8 GB  256 GB
# 651  DELL             AMD        Ryzen 3   Not Available   8 GB  512 GB
# 652  DELL             AMD        Ryzen 3   Not Available   8 GB    0 GB
# 654  DELL             AMD        Ryzen 3   Not Available   8 GB    0 GB
# 660  DELL             AMD        Ryzen 3   Not Available   8 GB    0 GB
# 662  DELL             AMD        Ryzen 5   Not Available   8 GB  256 GB
# 663  DELL             AMD        Ryzen 5   Not Available   8 GB  256 GB
# 664  DELL             AMD        Ryzen 5   Not Available   8 GB  256 GB
# 665  DELL             AMD        Ryzen 5   Not Available   8 GB  256 GB
# 679  DELL             AMD        Ryzen 5   Not Available   8 GB  512 GB
# 683  DELL             AMD        Ryzen 5   Not Available   8 GB  512 GB
# 695  DELL             AMD        Ryzen 5   Not Available   8 GB  512 GB
# 696  DELL             AMD        Ryzen 5   Not Available   8 GB  512 GB
# 729  DELL             AMD        Ryzen 5   Not Available   8 GB  256 GB
#
#          hdd  os_bit graphic_card_gb      weight     warranty Touchscreen  \
# 29      0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 36      0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 39      0 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 47      0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 48      0 GB  64-bit            0 GB      Casual       1 year         Yes
# 49      0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 50      0 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 82      0 GB  64-bit            0 GB      Casual       1 year          No
# 95      0 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 110     0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 111     0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 128     0 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 132  1024 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 133  1024 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 134  1024 GB  64-bit            0 GB  ThinNlight       1 year          No
# 137  1024 GB  32-bit            0 GB      Casual  No warranty          No
# 157  1024 GB  64-bit            0 GB  ThinNlight       1 year          No
# 162  1024 GB  32-bit            0 GB      Casual  No warranty          No
# 164  1024 GB  32-bit            0 GB      Casual  No warranty          No
# 168  1024 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 171  1024 GB  64-bit            0 GB  ThinNlight       1 year          No
# 172  1024 GB  64-bit            0 GB      Casual  No warranty          No
# 173  1024 GB  64-bit            0 GB      Casual  No warranty          No
# 177  1024 GB  64-bit            0 GB  ThinNlight       1 year          No
# 187  1024 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 209     0 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 293     0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 296     0 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 418  1024 GB  64-bit            0 GB  ThinNlight       1 year          No
# 426  1024 GB  32-bit            0 GB      Casual  No warranty          No
# 431  1024 GB  32-bit            0 GB      Casual  No warranty          No
# 446  1024 GB  64-bit            0 GB      Casual       1 year          No
# 458  1024 GB  64-bit            0 GB  ThinNlight       1 year          No
# 463  1024 GB  64-bit            0 GB  ThinNlight       1 year          No
# 471  1024 GB  64-bit            0 GB      Casual       1 year          No
# 638     0 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 639     0 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 640     0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 642     0 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 651     0 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 652  1024 GB  64-bit            0 GB  ThinNlight       1 year          No
# 654  1024 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 660  1024 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 662     0 GB  64-bit            0 GB      Casual       1 year          No
# 663     0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 664     0 GB  64-bit            0 GB      Casual       1 year          No
# 665     0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 679     0 GB  64-bit            0 GB  ThinNlight  No warranty          No
# 683     0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 695     0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 696     0 GB  64-bit            0 GB  ThinNlight       1 year          No
# 729  1024 GB  64-bit            0 GB      Casual  No warranty          No
#
#     msoffice  Price
# 29       Yes  39490
# 36       Yes  41990
# 39        No  42490
# 47        No  42990
# 48        No  49990
# 49       Yes  41490
# 50        No  41990
# 82        No  48500
# 95        No  45990
# 110      Yes  41990
# 111       No  45490
# 128       No  45930
# 132       No  42490
# 133       No  42190
# 134      Yes  39490
# 137       No  43800
# 157      Yes  37990
# 162       No  42900
# 164       No  41480
# 168       No  40390
# 171      Yes  41490
# 172       No  45490
# 173       No  44490
# 177       No  48990
# 187       No  46390
# 209       No  55990
# 293      Yes  55490
# 296       No  59990
# 418      Yes  48990
# 426       No  58090
# 431       No  58990
# 446       No  57990
# 458      Yes  54990
# 463      Yes  58990
# 471      Yes  58990
# 638       No  39490
# 639       No  36990
# 640       No  39990
# 642       No  40590
# 651       No  42090
# 652      Yes  35990
# 654       No  37390
# 660       No  39990
# 662      Yes  41990
# 663       No  44490
# 664      Yes  41990
# 665      Yes  44490
# 679       No  47490
# 683       No  59490
# 695      Yes  49990
# 696      Yes  59490
# 729       No  49490

# %%
DELL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 52 entries, 29 to 729
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            52 non-null     object
#  1   processor_brand  52 non-null     object
#  2   processor_name   52 non-null     object
#  3   processor_gnrtn  52 non-null     object
#  4   ram_gb           52 non-null     object
#  5   ssd              52 non-null     object
#  6   hdd              52 non-null     object
#  7   os_bit           52 non-null     object
#  8   graphic_card_gb  52 non-null     object
#  9   weight           52 non-null     object
#  10  warranty         52 non-null     object
#  11  Touchscreen      52 non-null     object
#  12  msoffice         52 non-null     object
#  13  Price            52 non-null     int64
# dtypes: int64(1), object(13)
# memory usage: 6.1+ KB

# %%
DELL = DELL[DELL['msoffice']=='Yes']

# %%
DELL
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb     ssd  \
# 29   DELL           Intel        Core i3            10th   8 GB  256 GB
# 36   DELL           Intel        Core i3            11th   8 GB  256 GB
# 49   DELL           Intel        Core i3            11th   8 GB  256 GB
# 110  DELL           Intel        Core i3            10th   8 GB  512 GB
# 134  DELL           Intel        Core i3            10th   8 GB    0 GB
# 157  DELL           Intel        Core i3            11th   8 GB    0 GB
# 171  DELL           Intel        Core i3            10th   8 GB  256 GB
# 293  DELL           Intel        Core i5            11th   8 GB  512 GB
# 418  DELL           Intel        Core i5            11th   8 GB    0 GB
# 458  DELL           Intel        Core i5            11th   8 GB  256 GB
# 463  DELL           Intel        Core i5            11th   8 GB  256 GB
# 471  DELL           Intel        Core i5            11th   8 GB  256 GB
# 652  DELL             AMD        Ryzen 3   Not Available   8 GB    0 GB
# 662  DELL             AMD        Ryzen 5   Not Available   8 GB  256 GB
# 664  DELL             AMD        Ryzen 5   Not Available   8 GB  256 GB
# 665  DELL             AMD        Ryzen 5   Not Available   8 GB  256 GB
# 695  DELL             AMD        Ryzen 5   Not Available   8 GB  512 GB
# 696  DELL             AMD        Ryzen 5   Not Available   8 GB  512 GB
#
#          hdd  os_bit graphic_card_gb      weight warranty Touchscreen  \
# 29      0 GB  64-bit            0 GB  ThinNlight   1 year          No
# 36      0 GB  64-bit            0 GB  ThinNlight   1 year          No
# 49      0 GB  64-bit            0 GB  ThinNlight   1 year          No
# 110     0 GB  64-bit            0 GB  ThinNlight   1 year          No
# 134  1024 GB  64-bit            0 GB  ThinNlight   1 year          No
# 157  1024 GB  64-bit            0 GB  ThinNlight   1 year          No
# 171  1024 GB  64-bit            0 GB  ThinNlight   1 year          No
# 293     0 GB  64-bit            0 GB  ThinNlight   1 year          No
# 418  1024 GB  64-bit            0 GB  ThinNlight   1 year          No
# 458  1024 GB  64-bit            0 GB  ThinNlight   1 year          No
# 463  1024 GB  64-bit            0 GB  ThinNlight   1 year          No
# 471  1024 GB  64-bit            0 GB      Casual   1 year          No
# 652  1024 GB  64-bit            0 GB  ThinNlight   1 year          No
# 662     0 GB  64-bit            0 GB      Casual   1 year          No
# 664     0 GB  64-bit            0 GB      Casual   1 year          No
# 665     0 GB  64-bit            0 GB  ThinNlight   1 year          No
# 695     0 GB  64-bit            0 GB  ThinNlight   1 year          No
# 696     0 GB  64-bit            0 GB  ThinNlight   1 year          No
#
#     msoffice  Price
# 29       Yes  39490
# 36       Yes  41990
# 49       Yes  41490
# 110      Yes  41990
# 134      Yes  39490
# 157      Yes  37990
# 171      Yes  41490
# 293      Yes  55490
# 418      Yes  48990
# 458      Yes  54990
# 463      Yes  58990
# 471      Yes  58990
# 652      Yes  35990
# 662      Yes  41990
# 664      Yes  41990
# 665      Yes  44490
# 695      Yes  49990
# 696      Yes  59490

# %%
DELL.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 18 entries, 29 to 696
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            18 non-null     object
#  1   processor_brand  18 non-null     object
#  2   processor_name   18 non-null     object
#  3   processor_gnrtn  18 non-null     object
#  4   ram_gb           18 non-null     object
#  5   ssd              18 non-null     object
#  6   hdd              18 non-null     object
#  7   os_bit           18 non-null     object
#  8   graphic_card_gb  18 non-null     object
#  9   weight           18 non-null     object
#  10  warranty         18 non-null     object
#  11  Touchscreen      18 non-null     object
#  12  msoffice         18 non-null     object
#  13  Price            18 non-null     int64
# dtypes: int64(1), object(13)
# memory usage: 2.1+ KB

# %%
DELL = DELL[DELL['ssd']!='0 GB']

# %%
DELL
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb     ssd  \
# 29   DELL           Intel        Core i3            10th   8 GB  256 GB
# 36   DELL           Intel        Core i3            11th   8 GB  256 GB
# 49   DELL           Intel        Core i3            11th   8 GB  256 GB
# 110  DELL           Intel        Core i3            10th   8 GB  512 GB
# 171  DELL           Intel        Core i3            10th   8 GB  256 GB
# 293  DELL           Intel        Core i5            11th   8 GB  512 GB
# 458  DELL           Intel        Core i5            11th   8 GB  256 GB
# 463  DELL           Intel        Core i5            11th   8 GB  256 GB
# 471  DELL           Intel        Core i5            11th   8 GB  256 GB
# 662  DELL             AMD        Ryzen 5   Not Available   8 GB  256 GB
# 664  DELL             AMD        Ryzen 5   Not Available   8 GB  256 GB
# 665  DELL             AMD        Ryzen 5   Not Available   8 GB  256 GB
# 695  DELL             AMD        Ryzen 5   Not Available   8 GB  512 GB
# 696  DELL             AMD        Ryzen 5   Not Available   8 GB  512 GB
#
#          hdd  os_bit graphic_card_gb      weight warranty Touchscreen  \
# 29      0 GB  64-bit            0 GB  ThinNlight   1 year          No
# 36      0 GB  64-bit            0 GB  ThinNlight   1 year          No
# 49      0 GB  64-bit            0 GB  ThinNlight   1 year          No
# 110     0 GB  64-bit            0 GB  ThinNlight   1 year          No
# 171  1024 GB  64-bit            0 GB  ThinNlight   1 year          No
# 293     0 GB  64-bit            0 GB  ThinNlight   1 year          No
# 458  1024 GB  64-bit            0 GB  ThinNlight   1 year          No
# 463  1024 GB  64-bit            0 GB  ThinNlight   1 year          No
# 471  1024 GB  64-bit            0 GB      Casual   1 year          No
# 662     0 GB  64-bit            0 GB      Casual   1 year          No
# 664     0 GB  64-bit            0 GB      Casual   1 year          No
# 665     0 GB  64-bit            0 GB  ThinNlight   1 year          No
# 695     0 GB  64-bit            0 GB  ThinNlight   1 year          No
# 696     0 GB  64-bit            0 GB  ThinNlight   1 year          No
#
#     msoffice  Price
# 29       Yes  39490
# 36       Yes  41990
# 49       Yes  41490
# 110      Yes  41990
# 171      Yes  41490
# 293      Yes  55490
# 458      Yes  54990
# 463      Yes  58990
# 471      Yes  58990
# 662      Yes  41990
# 664      Yes  41990
# 665      Yes  44490
# 695      Yes  49990
# 696      Yes  59490

# %%
DELL = DELL[DELL['processor_brand']=="AMD"]

# %%
DELL
# Out:
#     brand processor_brand processor_name processor_gnrtn ram_gb     ssd   hdd  \
# 662  DELL             AMD        Ryzen 5   Not Available   8 GB  256 GB  0 GB
# 664  DELL             AMD        Ryzen 5   Not Available   8 GB  256 GB  0 GB
# 665  DELL             AMD        Ryzen 5   Not Available   8 GB  256 GB  0 GB
# 695  DELL             AMD        Ryzen 5   Not Available   8 GB  512 GB  0 GB
# 696  DELL             AMD        Ryzen 5   Not Available   8 GB  512 GB  0 GB
#
#      os_bit graphic_card_gb      weight warranty Touchscreen msoffice  Price
# 662  64-bit            0 GB      Casual   1 year          No      Yes  41990
# 664  64-bit            0 GB      Casual   1 year          No      Yes  41990
# 665  64-bit            0 GB  ThinNlight   1 year          No      Yes  44490
# 695  64-bit            0 GB  ThinNlight   1 year          No      Yes  49990
# 696  64-bit            0 GB  ThinNlight   1 year          No      Yes  59490

# %%
print("Total no. of laptops matching the given condition is ",len(DELL))
# Out:
# Total no. of laptops matching the given condition is  5

# %% [markdown]
# ### Ans : 5 Laptops

# %% [markdown]
# ### Column Encoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 802 entries, 0 to 822
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   brand            802 non-null    object
#  1   processor_brand  802 non-null    object
#  2   processor_name   802 non-null    object
#  3   processor_gnrtn  802 non-null    object
#  4   ram_gb           802 non-null    object
#  5   ssd              802 non-null    object
#  6   hdd              802 non-null    object
#  7   os_bit           802 non-null    object
#  8   graphic_card_gb  802 non-null    object
#  9   weight           802 non-null    object
#  10  warranty         802 non-null    object
#  11  Touchscreen      802 non-null    object
#  12  msoffice         802 non-null    object
#  13  Price            802 non-null    int64
# dtypes: int64(1), object(13)
# memory usage: 94.0+ KB

# %%
print(df['ram_gb'].dtype)
# Out:
# object

# %%
df['ram_gb'].unique()
# Out:
# array(['4 GB', '8 GB', '16 GB', '32 GB'], dtype=object)

# %%
df['ram_gb'].nunique()
# Out:
# 4

# %%
dct ={ '4 GB':4,
       '8 GB':8,
       '16 GB':16,
       '32 GB':32,
      }
#converting object to int

# %%
df['ram_gb'] = df['ram_gb'].map(dct)

# %%
print(df['ram_gb'].dtype)
# Out:
# int64

# %% [markdown]
# ### Encoding successfull

# %%
df
# Out:
#       brand processor_brand processor_name processor_gnrtn  ram_gb      ssd  \
# 0      ASUS           Intel        Core i3            10th       4     0 GB
# 1    Lenovo           Intel        Core i3            10th       4     0 GB
# 2    Lenovo           Intel        Core i3            10th       4     0 GB
# 3      ASUS           Intel        Core i5            10th       8   512 GB
# 4      ASUS           Intel   Celeron Dual   Not Available       4     0 GB
# ..      ...             ...            ...             ...     ...      ...
# 818    ASUS             AMD        Ryzen 9   Not Available       4  1024 GB
# 819    ASUS             AMD        Ryzen 9   Not Available       4  1024 GB
# 820    ASUS             AMD        Ryzen 9   Not Available       4  1024 GB
# 821    ASUS             AMD        Ryzen 9   Not Available       4  1024 GB
# 822  Lenovo             AMD        Ryzen 5            10th       8   512 GB
#
#          hdd  os_bit graphic_card_gb      weight     warranty Touchscreen  \
# 0    1024 GB  64-bit            0 GB      Casual  No warranty          No
# 1    1024 GB  64-bit            0 GB      Casual  No warranty          No
# 2    1024 GB  64-bit            0 GB      Casual  No warranty          No
# 3       0 GB  32-bit            2 GB      Casual  No warranty          No
# 4     512 GB  64-bit            0 GB      Casual  No warranty          No
# ..       ...     ...             ...         ...          ...         ...
# 818     0 GB  64-bit            0 GB      Casual       1 year          No
# 819     0 GB  64-bit            0 GB      Casual       1 year          No
# 820     0 GB  64-bit            4 GB      Casual       1 year          No
# 821     0 GB  64-bit            4 GB      Casual       1 year          No
# 822     0 GB  64-bit            0 GB  ThinNlight  No warranty          No
#
#     msoffice   Price
# 0         No   34649
# 1         No   38999
# 2         No   39999
# 3         No   69990
# 4         No   26990
# ..       ...     ...
# 818       No  135990
# 819       No  144990
# 820       No  149990
# 821       No  142990
# 822       No   57490
#
# [802 rows x 14 columns]

# %% [markdown]
# ### Making new updated csv file after encoding

# %%
df.to_csv('updated_laptopPrice_csv')
