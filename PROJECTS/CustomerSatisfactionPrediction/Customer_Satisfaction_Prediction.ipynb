# %% [markdown]
#  > #   CUSTOMER SATISFACTION PREDICTION

# %% [markdown]
#  #### ***This project is made using PANDAS module***

# %% [markdown]
# ### Loading csv data file

# %%
import pandas as  pd
import numpy as np

# %%
df = pd.read_csv('cust_satisfaction.csv')

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# 2                     satisfied   26             1142                       5
# 3       neutral or dissatisfied   25              562                       2
# 4                     satisfied   61              214                       3
# ...                         ...  ...              ...                     ...
# 103899  neutral or dissatisfied   23              192                       2
# 103900                satisfied   49             2347                       5
# 103901  neutral or dissatisfied   30             1995                       4
# 103902  neutral or dissatisfied   22             1000                       1
# 103903  neutral or dissatisfied   27             1723                       1
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                      4            5                          25
# 1                      3            1                           1
# 2                      4            5                           0
# 3                      3            2                          11
# 4                      4            3                           0
# ...                  ...          ...                         ...
# 103899                 4            2                           3
# 103900                 5            4                           0
# 103901                 4            4                           7
# 103902                 1            1                           0
# 103903                 4            1                           0
#
#         Arrival Delay in Minutes
# 0                           18.0
# 1                            6.0
# 2                            0.0
# 3                            9.0
# 4                            0.0
# ...                          ...
# 103899                       0.0
# 103900                       0.0
# 103901                      14.0
# 103902                       0.0
# 103903                       0.0
#
# [103904 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 103904 entries, 0 to 103903
# Data columns (total 12 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103904 non-null  object
#  1   Customer Type               103904 non-null  object
#  2   Type of Travel              103904 non-null  object
#  3   Class                       103904 non-null  object
#  4   satisfaction                103904 non-null  object
#  5   Age                         103904 non-null  int64
#  6   Flight Distance             103904 non-null  int64
#  7   Inflight entertainment      103904 non-null  int64
#  8   Baggage handling            103904 non-null  int64
#  9   Cleanliness                 103904 non-null  int64
#  10  Departure Delay in Minutes  103904 non-null  int64
#  11  Arrival Delay in Minutes    103594 non-null  float64
# dtypes: float64(1), int64(6), object(5)
# memory usage: 9.5+ MB

# %% [markdown]
# ### Removing duplicates

# %%
df.duplicated()
# Out:
# 0         False
# 1         False
# 2         False
# 3         False
# 4         False
#           ...
# 103899    False
# 103900    False
# 103901    False
# 103902    False
# 103903    False
# Length: 103904, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(172)

# %%
df.drop_duplicates()
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# 2                     satisfied   26             1142                       5
# 3       neutral or dissatisfied   25              562                       2
# 4                     satisfied   61              214                       3
# ...                         ...  ...              ...                     ...
# 103899  neutral or dissatisfied   23              192                       2
# 103900                satisfied   49             2347                       5
# 103901  neutral or dissatisfied   30             1995                       4
# 103902  neutral or dissatisfied   22             1000                       1
# 103903  neutral or dissatisfied   27             1723                       1
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                      4            5                          25
# 1                      3            1                           1
# 2                      4            5                           0
# 3                      3            2                          11
# 4                      4            3                           0
# ...                  ...          ...                         ...
# 103899                 4            2                           3
# 103900                 5            4                           0
# 103901                 4            4                           7
# 103902                 1            1                           0
# 103903                 4            1                           0
#
#         Arrival Delay in Minutes
# 0                           18.0
# 1                            6.0
# 2                            0.0
# 3                            9.0
# 4                            0.0
# ...                          ...
# 103899                       0.0
# 103900                       0.0
# 103901                      14.0
# 103902                       0.0
# 103903                       0.0
#
# [103732 rows x 12 columns]

# %%
df.drop_duplicates(inplace=True) # inplace=True removes duplicates permanently from the original DataFrame

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# 2                     satisfied   26             1142                       5
# 3       neutral or dissatisfied   25              562                       2
# 4                     satisfied   61              214                       3
# ...                         ...  ...              ...                     ...
# 103899  neutral or dissatisfied   23              192                       2
# 103900                satisfied   49             2347                       5
# 103901  neutral or dissatisfied   30             1995                       4
# 103902  neutral or dissatisfied   22             1000                       1
# 103903  neutral or dissatisfied   27             1723                       1
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                      4            5                          25
# 1                      3            1                           1
# 2                      4            5                           0
# 3                      3            2                          11
# 4                      4            3                           0
# ...                  ...          ...                         ...
# 103899                 4            2                           3
# 103900                 5            4                           0
# 103901                 4            4                           7
# 103902                 1            1                           0
# 103903                 4            1                           0
#
#         Arrival Delay in Minutes
# 0                           18.0
# 1                            6.0
# 2                            0.0
# 3                            9.0
# 4                            0.0
# ...                          ...
# 103899                       0.0
# 103900                       0.0
# 103901                      14.0
# 103902                       0.0
# 103903                       0.0
#
# [103732 rows x 12 columns]

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# 2                     satisfied   26             1142                       5
# 3       neutral or dissatisfied   25              562                       2
# 4                     satisfied   61              214                       3
# ...                         ...  ...              ...                     ...
# 103899  neutral or dissatisfied   23              192                       2
# 103900                satisfied   49             2347                       5
# 103901  neutral or dissatisfied   30             1995                       4
# 103902  neutral or dissatisfied   22             1000                       1
# 103903  neutral or dissatisfied   27             1723                       1
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                      4            5                          25
# 1                      3            1                           1
# 2                      4            5                           0
# 3                      3            2                          11
# 4                      4            3                           0
# ...                  ...          ...                         ...
# 103899                 4            2                           3
# 103900                 5            4                           0
# 103901                 4            4                           7
# 103902                 1            1                           0
# 103903                 4            1                           0
#
#         Arrival Delay in Minutes
# 0                           18.0
# 1                            6.0
# 2                            0.0
# 3                            9.0
# 4                            0.0
# ...                          ...
# 103899                       0.0
# 103900                       0.0
# 103901                      14.0
# 103902                       0.0
# 103903                       0.0
#
# [103732 rows x 12 columns]

# %% [markdown]
# ### Removing null values if exist

# %%
df.isnull()
# Out:
#         Gender  Customer Type  Type of Travel  Class  satisfaction    Age  \
# 0        False          False           False  False         False  False
# 1        False          False           False  False         False  False
# 2        False          False           False  False         False  False
# 3        False          False           False  False         False  False
# 4        False          False           False  False         False  False
# ...        ...            ...             ...    ...           ...    ...
# 103899   False          False           False  False         False  False
# 103900   False          False           False  False         False  False
# 103901   False          False           False  False         False  False
# 103902   False          False           False  False         False  False
# 103903   False          False           False  False         False  False
#
#         Flight Distance  Inflight entertainment  Baggage handling  \
# 0                 False                   False             False
# 1                 False                   False             False
# 2                 False                   False             False
# 3                 False                   False             False
# 4                 False                   False             False
# ...                 ...                     ...               ...
# 103899            False                   False             False
# 103900            False                   False             False
# 103901            False                   False             False
# 103902            False                   False             False
# 103903            False                   False             False
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 0             False                       False                     False
# 1             False                       False                     False
# 2             False                       False                     False
# 3             False                       False                     False
# 4             False                       False                     False
# ...             ...                         ...                       ...
# 103899        False                       False                     False
# 103900        False                       False                     False
# 103901        False                       False                     False
# 103902        False                       False                     False
# 103903        False                       False                     False
#
# [103732 rows x 12 columns]

# %%
df.isnull().sum()
# Out:
# Gender                          0
# Customer Type                   0
# Type of Travel                  0
# Class                           0
# satisfaction                    0
# Age                             0
# Flight Distance                 0
# Inflight entertainment          0
# Baggage handling                0
# Cleanliness                     0
# Departure Delay in Minutes      0
# Arrival Delay in Minutes      310
# dtype: int64

# %%
df.dropna(inplace=True) #drop null value and place to df and return none

# %%
df.isnull().sum()
# Out:
# Gender                        0
# Customer Type                 0
# Type of Travel                0
# Class                         0
# satisfaction                  0
# Age                           0
# Flight Distance               0
# Inflight entertainment        0
# Baggage handling              0
# Cleanliness                   0
# Departure Delay in Minutes    0
# Arrival Delay in Minutes      0
# dtype: int64

# %%
df.describe()
# Out:
#                  Age  Flight Distance  Inflight entertainment  \
# count  103422.000000    103422.000000           103422.000000
# mean       39.377057      1189.611707                3.357583
# std        15.115713       997.510488                1.333102
# min         7.000000        31.000000                0.000000
# 25%        27.000000       414.000000                2.000000
# 50%        40.000000       843.000000                4.000000
# 75%        51.000000      1744.000000                4.000000
# max        85.000000      4983.000000                5.000000
#
#        Baggage handling    Cleanliness  Departure Delay in Minutes  \
# count     103422.000000  103422.000000               103422.000000
# mean           3.630649       3.285926                   14.772447
# std            1.181313       1.312334                   38.143678
# min            1.000000       0.000000                    0.000000
# 25%            3.000000       2.000000                    0.000000
# 50%            4.000000       3.000000                    0.000000
# 75%            5.000000       4.000000                   12.000000
# max            5.000000       5.000000                 1592.000000
#
#        Arrival Delay in Minutes
# count             103422.000000
# mean                  15.203922
# std                   38.725894
# min                    0.000000
# 25%                    0.000000
# 50%                    0.000000
# 75%                   13.000000
# max                 1584.000000

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# 2                     satisfied   26             1142                       5
# 3       neutral or dissatisfied   25              562                       2
# 4                     satisfied   61              214                       3
# ...                         ...  ...              ...                     ...
# 103899  neutral or dissatisfied   23              192                       2
# 103900                satisfied   49             2347                       5
# 103901  neutral or dissatisfied   30             1995                       4
# 103902  neutral or dissatisfied   22             1000                       1
# 103903  neutral or dissatisfied   27             1723                       1
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                      4            5                          25
# 1                      3            1                           1
# 2                      4            5                           0
# 3                      3            2                          11
# 4                      4            3                           0
# ...                  ...          ...                         ...
# 103899                 4            2                           3
# 103900                 5            4                           0
# 103901                 4            4                           7
# 103902                 1            1                           0
# 103903                 4            1                           0
#
#         Arrival Delay in Minutes
# 0                           18.0
# 1                            6.0
# 2                            0.0
# 3                            9.0
# 4                            0.0
# ...                          ...
# 103899                       0.0
# 103900                       0.0
# 103901                      14.0
# 103902                       0.0
# 103903                       0.0
#
# [103422 rows x 12 columns]

# %% [markdown]
# ### Dropping unnecessary columns

# %%
df.columns
# Out:
# Index(['Gender', 'Customer Type', 'Type of Travel', 'Class', 'satisfaction',
#        'Age', 'Flight Distance', 'Inflight entertainment', 'Baggage handling',
#        'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='object')

# %%
df
# Out:
#         Gender      Customer Type   Type of Travel     Class  \
# 0         Male     Loyal Customer  Personal Travel  Eco Plus
# 1         Male  disloyal Customer  Business travel  Business
# 2       Female     Loyal Customer  Business travel  Business
# 3       Female     Loyal Customer  Business travel  Business
# 4         Male     Loyal Customer  Business travel  Business
# ...        ...                ...              ...       ...
# 103899  Female  disloyal Customer  Business travel       Eco
# 103900    Male     Loyal Customer  Business travel  Business
# 103901    Male  disloyal Customer  Business travel  Business
# 103902  Female  disloyal Customer  Business travel       Eco
# 103903    Male     Loyal Customer  Business travel  Business
#
#                    satisfaction  Age  Flight Distance  Inflight entertainment  \
# 0       neutral or dissatisfied   13              460                       5
# 1       neutral or dissatisfied   25              235                       1
# 2                     satisfied   26             1142                       5
# 3       neutral or dissatisfied   25              562                       2
# 4                     satisfied   61              214                       3
# ...                         ...  ...              ...                     ...
# 103899  neutral or dissatisfied   23              192                       2
# 103900                satisfied   49             2347                       5
# 103901  neutral or dissatisfied   30             1995                       4
# 103902  neutral or dissatisfied   22             1000                       1
# 103903  neutral or dissatisfied   27             1723                       1
#
#         Baggage handling  Cleanliness  Departure Delay in Minutes  \
# 0                      4            5                          25
# 1                      3            1                           1
# 2                      4            5                           0
# 3                      3            2                          11
# 4                      4            3                           0
# ...                  ...          ...                         ...
# 103899                 4            2                           3
# 103900                 5            4                           0
# 103901                 4            4                           7
# 103902                 1            1                           0
# 103903                 4            1                           0
#
#         Arrival Delay in Minutes
# 0                           18.0
# 1                            6.0
# 2                            0.0
# 3                            9.0
# 4                            0.0
# ...                          ...
# 103899                       0.0
# 103900                       0.0
# 103901                      14.0
# 103902                       0.0
# 103903                       0.0
#
# [103422 rows x 12 columns]

# %%
df.drop(
    ['Customer Type', 'Inflight entertainment', 'Baggage handling'],
    axis=1,
    inplace=True
)

# %%
df
# Out:
#         Gender   Type of Travel     Class             satisfaction  Age  \
# 0         Male  Personal Travel  Eco Plus  neutral or dissatisfied   13
# 1         Male  Business travel  Business  neutral or dissatisfied   25
# 2       Female  Business travel  Business                satisfied   26
# 3       Female  Business travel  Business  neutral or dissatisfied   25
# 4         Male  Business travel  Business                satisfied   61
# ...        ...              ...       ...                      ...  ...
# 103899  Female  Business travel       Eco  neutral or dissatisfied   23
# 103900    Male  Business travel  Business                satisfied   49
# 103901    Male  Business travel  Business  neutral or dissatisfied   30
# 103902  Female  Business travel       Eco  neutral or dissatisfied   22
# 103903    Male  Business travel  Business  neutral or dissatisfied   27
#
#         Flight Distance  Cleanliness  Departure Delay in Minutes  \
# 0                   460            5                          25
# 1                   235            1                           1
# 2                  1142            5                           0
# 3                   562            2                          11
# 4                   214            3                           0
# ...                 ...          ...                         ...
# 103899              192            2                           3
# 103900             2347            4                           0
# 103901             1995            4                           7
# 103902             1000            1                           0
# 103903             1723            1                           0
#
#         Arrival Delay in Minutes
# 0                           18.0
# 1                            6.0
# 2                            0.0
# 3                            9.0
# 4                            0.0
# ...                          ...
# 103899                       0.0
# 103900                       0.0
# 103901                      14.0
# 103902                       0.0
# 103903                       0.0
#
# [103422 rows x 9 columns]

# %%
df.columns
# Out:
# Index(['Gender', 'Type of Travel', 'Class', 'satisfaction', 'Age',
#        'Flight Distance', 'Cleanliness', 'Departure Delay in Minutes',
#        'Arrival Delay in Minutes'],
#       dtype='object')

# %% [markdown]
# ## ❓ Question
#
# Find the number of customers who:
#
# - Are Female
# - Age between 30 and 50
# - Flight Distance < 1500
# - ECO-PLUS Passenger
# - Satisfied
# - Cleanliness <2

# %%
PASSENGER= df[df['Gender']=="Female"]

# %%
PASSENGER
# Out:
#         Gender   Type of Travel     Class             satisfaction  Age  \
# 2       Female  Business travel  Business                satisfied   26
# 3       Female  Business travel  Business  neutral or dissatisfied   25
# 5       Female  Personal Travel       Eco  neutral or dissatisfied   26
# 7       Female  Business travel  Business                satisfied   52
# 8       Female  Business travel  Business  neutral or dissatisfied   41
# ...        ...              ...       ...                      ...  ...
# 103893  Female  Business travel  Business  neutral or dissatisfied   58
# 103895  Female  Business travel       Eco  neutral or dissatisfied   24
# 103897  Female  Business travel  Business                satisfied   60
# 103899  Female  Business travel       Eco  neutral or dissatisfied   23
# 103902  Female  Business travel       Eco  neutral or dissatisfied   22
#
#         Flight Distance  Cleanliness  Departure Delay in Minutes  \
# 2                  1142            5                           0
# 3                   562            2                          11
# 5                  1180            1                           0
# 7                  2035            4                           4
# 8                   853            2                           0
# ...                 ...          ...                         ...
# 103893              296            1                           0
# 103895             1055            1                          13
# 103897             1599            4                           9
# 103899              192            2                           3
# 103902             1000            1                           0
#
#         Arrival Delay in Minutes
# 2                            0.0
# 3                            9.0
# 5                            0.0
# 7                            0.0
# 8                            0.0
# ...                          ...
# 103893                      29.0
# 103895                      10.0
# 103897                       7.0
# 103899                       0.0
# 103902                       0.0
#
# [52500 rows x 9 columns]

# %%
df['satisfaction'].unique()
# Out:
# array(['neutral or dissatisfied', 'satisfied'], dtype=object)

# %%
PASSENGER= PASSENGER[PASSENGER['satisfaction']=="satisfied"]

# %%
PASSENGER
# Out:
#         Gender   Type of Travel     Class satisfaction  Age  Flight Distance  \
# 2       Female  Business travel  Business    satisfied   26             1142
# 7       Female  Business travel  Business    satisfied   52             2035
# 16      Female  Business travel  Business    satisfied   26             2123
# 18      Female  Business travel  Business    satisfied   45             2486
# 24      Female  Business travel       Eco    satisfied   23              452
# ...        ...              ...       ...          ...  ...              ...
# 103881  Female  Business travel  Business    satisfied   51              384
# 103887  Female  Personal Travel       Eco    satisfied   51             1222
# 103889  Female  Business travel  Business    satisfied   43             3885
# 103890  Female  Business travel  Eco Plus    satisfied   56              550
# 103897  Female  Business travel  Business    satisfied   60             1599
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 2                 5                           0                       0.0
# 7                 4                           4                       0.0
# 16                4                          49                      51.0
# 18                4                           7                       5.0
# 24                1                          54                      44.0
# ...             ...                         ...                       ...
# 103881            3                          54                      51.0
# 103887            4                           4                       0.0
# 103889            3                           0                       0.0
# 103890            3                           0                       0.0
# 103897            4                           9                       7.0
#
# [22415 rows x 9 columns]

# %%
PASSENGER= PASSENGER[(PASSENGER['Age']>30)&(PASSENGER['Age']<50)]

# %%
PASSENGER
# Out:
#         Gender   Type of Travel     Class satisfaction  Age  Flight Distance  \
# 18      Female  Business travel  Business    satisfied   45             2486
# 26      Female  Business travel  Business    satisfied   33             1561
# 27      Female  Business travel  Eco Plus    satisfied   49              315
# 30      Female  Business travel  Business    satisfied   31              819
# 32      Female  Business travel  Business    satisfied   35             2611
# ...        ...              ...       ...          ...  ...              ...
# 103843  Female  Business travel  Business    satisfied   42             1076
# 103853  Female  Business travel       Eco    satisfied   49              760
# 103861  Female  Business travel       Eco    satisfied   38              821
# 103870  Female  Business travel  Business    satisfied   48             1990
# 103889  Female  Business travel  Business    satisfied   43             3885
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 18                4                           7                       5.0
# 26                2                           0                       0.0
# 27                2                           0                       8.0
# 30                5                           0                       0.0
# 32                4                         109                     120.0
# ...             ...                         ...                       ...
# 103843            5                         171                     156.0
# 103853            5                           0                      21.0
# 103861            4                          23                       0.0
# 103870            4                           0                       0.0
# 103889            3                           0                       0.0
#
# [10643 rows x 9 columns]

# %%
PASSENGER.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10643 entries, 18 to 103889
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count  Dtype
# ---  ------                      --------------  -----
#  0   Gender                      10643 non-null  object
#  1   Type of Travel              10643 non-null  object
#  2   Class                       10643 non-null  object
#  3   satisfaction                10643 non-null  object
#  4   Age                         10643 non-null  int64
#  5   Flight Distance             10643 non-null  int64
#  6   Cleanliness                 10643 non-null  int64
#  7   Departure Delay in Minutes  10643 non-null  int64
#  8   Arrival Delay in Minutes    10643 non-null  float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 831.5+ KB

# %%
PASSENGER= PASSENGER[PASSENGER['Flight Distance']<1500]

# %%
PASSENGER
# Out:
#         Gender   Type of Travel     Class satisfaction  Age  Flight Distance  \
# 27      Female  Business travel  Eco Plus    satisfied   49              315
# 30      Female  Business travel  Business    satisfied   31              819
# 38      Female  Personal Travel       Eco    satisfied   47              302
# 69      Female  Business travel  Eco Plus    satisfied   38              157
# 91      Female  Business travel  Business    satisfied   41              304
# ...        ...              ...       ...          ...  ...              ...
# 103815  Female  Business travel       Eco    satisfied   42             1121
# 103832  Female  Business travel       Eco    satisfied   49              639
# 103843  Female  Business travel  Business    satisfied   42             1076
# 103853  Female  Business travel       Eco    satisfied   49              760
# 103861  Female  Business travel       Eco    satisfied   38              821
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 27                2                           0                       8.0
# 30                5                           0                       0.0
# 38                4                          23                      31.0
# 69                4                           0                       0.0
# 91                2                          31                      19.0
# ...             ...                         ...                       ...
# 103815            2                           1                       0.0
# 103832            2                         225                     222.0
# 103843            5                         171                     156.0
# 103853            5                           0                      21.0
# 103861            4                          23                       0.0
#
# [5354 rows x 9 columns]

# %%
PASSENGER= PASSENGER[PASSENGER['Class']=='Eco Plus']

# %%
PASSENGER
# Out:
#         Gender   Type of Travel     Class satisfaction  Age  Flight Distance  \
# 27      Female  Business travel  Eco Plus    satisfied   49              315
# 69      Female  Business travel  Eco Plus    satisfied   38              157
# 375     Female  Business travel  Eco Plus    satisfied   37              174
# 403     Female  Business travel  Eco Plus    satisfied   48              907
# 546     Female  Business travel  Eco Plus    satisfied   40              809
# ...        ...              ...       ...          ...  ...              ...
# 103149  Female  Business travel  Eco Plus    satisfied   44              526
# 103306  Female  Business travel  Eco Plus    satisfied   46              191
# 103377  Female  Business travel  Eco Plus    satisfied   32             1250
# 103454  Female  Business travel  Eco Plus    satisfied   49              438
# 103674  Female  Business travel  Eco Plus    satisfied   41              391
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 27                2                           0                       8.0
# 69                4                           0                       0.0
# 375               5                           0                       0.0
# 403               5                           0                       1.0
# 546               4                         118                     100.0
# ...             ...                         ...                       ...
# 103149            1                           0                       0.0
# 103306            4                           0                       0.0
# 103377            5                           0                       0.0
# 103454            2                           0                       0.0
# 103674            2                           0                       0.0
#
# [383 rows x 9 columns]

# %%
PASSENGER= PASSENGER[PASSENGER['Cleanliness']<2]

# %%
PASSENGER
# Out:
#         Gender   Type of Travel     Class satisfaction  Age  Flight Distance  \
# 2455    Female  Business travel  Eco Plus    satisfied   49              370
# 5226    Female  Business travel  Eco Plus    satisfied   44             1050
# 13343   Female  Business travel  Eco Plus    satisfied   33             1208
# 16095   Female  Business travel  Eco Plus    satisfied   49              391
# 16701   Female  Personal Travel  Eco Plus    satisfied   32              670
# 24053   Female  Business travel  Eco Plus    satisfied   49             1190
# 25565   Female  Business travel  Eco Plus    satisfied   45              414
# 26989   Female  Business travel  Eco Plus    satisfied   46              386
# 29852   Female  Business travel  Eco Plus    satisfied   48              240
# 48361   Female  Business travel  Eco Plus    satisfied   49              438
# 49455   Female  Business travel  Eco Plus    satisfied   45              509
# 55025   Female  Business travel  Eco Plus    satisfied   43              231
# 57375   Female  Business travel  Eco Plus    satisfied   48              145
# 58264   Female  Personal Travel  Eco Plus    satisfied   36              304
# 59485   Female  Business travel  Eco Plus    satisfied   42              594
# 61397   Female  Personal Travel  Eco Plus    satisfied   45              802
# 63631   Female  Business travel  Eco Plus    satisfied   46              280
# 64945   Female  Business travel  Eco Plus    satisfied   47              216
# 80078   Female  Business travel  Eco Plus    satisfied   32              395
# 80161   Female  Business travel  Eco Plus    satisfied   42              566
# 81491   Female  Business travel  Eco Plus    satisfied   49              641
# 82181   Female  Business travel  Eco Plus    satisfied   42              525
# 85964   Female  Business travel  Eco Plus    satisfied   42              645
# 87328   Female  Personal Travel  Eco Plus    satisfied   43              462
# 89173   Female  Personal Travel  Eco Plus    satisfied   32              189
# 96439   Female  Personal Travel  Eco Plus    satisfied   44              551
# 97515   Female  Business travel  Eco Plus    satisfied   39              101
# 103149  Female  Business travel  Eco Plus    satisfied   44              526
#
#         Cleanliness  Departure Delay in Minutes  Arrival Delay in Minutes
# 2455              1                           0                       0.0
# 5226              1                           0                       0.0
# 13343             1                          15                       0.0
# 16095             1                           0                       0.0
# 16701             1                           0                       0.0
# 24053             1                           0                       0.0
# 25565             1                           0                       0.0
# 26989             1                           3                       0.0
# 29852             1                           0                       0.0
# 48361             1                           0                       0.0
# 49455             1                           0                       0.0
# 55025             1                           0                       0.0
# 57375             1                           0                       0.0
# 58264             1                           4                       0.0
# 59485             1                           0                       0.0
# 61397             1                           0                       0.0
# 63631             1                           0                       0.0
# 64945             1                           0                       0.0
# 80078             1                           1                       0.0
# 80161             1                           0                       0.0
# 81491             1                           0                       0.0
# 82181             1                           0                       0.0
# 85964             1                           0                       0.0
# 87328             1                           0                       0.0
# 89173             1                           1                       0.0
# 96439             1                           0                       0.0
# 97515             1                           0                       0.0
# 103149            1                           0                       0.0

# %%
print("Total no. of PASSENGERS matching the given condition is ",len(PASSENGER))
# Out:
# Total no. of PASSENGERS matching the given condition is  28

# %% [markdown]
# ### Ans : 28 Laptops

# %% [markdown]
# ### Column Encoding

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 103422 entries, 0 to 103903
# Data columns (total 9 columns):
#  #   Column                      Non-Null Count   Dtype
# ---  ------                      --------------   -----
#  0   Gender                      103422 non-null  object
#  1   Type of Travel              103422 non-null  object
#  2   Class                       103422 non-null  object
#  3   satisfaction                103422 non-null  object
#  4   Age                         103422 non-null  int64
#  5   Flight Distance             103422 non-null  int64
#  6   Cleanliness                 103422 non-null  int64
#  7   Departure Delay in Minutes  103422 non-null  int64
#  8   Arrival Delay in Minutes    103422 non-null  float64
# dtypes: float64(1), int64(4), object(4)
# memory usage: 7.9+ MB

# %%
print(df['Gender'].dtype)
# Out:
# object

# %%
df['Gender'].unique()
# Out:
# array(['Male', 'Female'], dtype=object)

# %%
df['Gender'].nunique()
# Out:
# 2

# %%
dct ={ 'Male':0 , 
       'Female':1
      }
#converting object to int

# %%
df['Gender'] = df['Gender'].map(dct)

# %%
print(df['Gender'].dtype)
# Out:
# int64

# %% [markdown]
# ### Encoding successfull

# %%
df
# Out:
#         Gender   Type of Travel     Class             satisfaction  Age  \
# 0            0  Personal Travel  Eco Plus  neutral or dissatisfied   13
# 1            0  Business travel  Business  neutral or dissatisfied   25
# 2            1  Business travel  Business                satisfied   26
# 3            1  Business travel  Business  neutral or dissatisfied   25
# 4            0  Business travel  Business                satisfied   61
# ...        ...              ...       ...                      ...  ...
# 103899       1  Business travel       Eco  neutral or dissatisfied   23
# 103900       0  Business travel  Business                satisfied   49
# 103901       0  Business travel  Business  neutral or dissatisfied   30
# 103902       1  Business travel       Eco  neutral or dissatisfied   22
# 103903       0  Business travel  Business  neutral or dissatisfied   27
#
#         Flight Distance  Cleanliness  Departure Delay in Minutes  \
# 0                   460            5                          25
# 1                   235            1                           1
# 2                  1142            5                           0
# 3                   562            2                          11
# 4                   214            3                           0
# ...                 ...          ...                         ...
# 103899              192            2                           3
# 103900             2347            4                           0
# 103901             1995            4                           7
# 103902             1000            1                           0
# 103903             1723            1                           0
#
#         Arrival Delay in Minutes
# 0                           18.0
# 1                            6.0
# 2                            0.0
# 3                            9.0
# 4                            0.0
# ...                          ...
# 103899                       0.0
# 103900                       0.0
# 103901                      14.0
# 103902                       0.0
# 103903                       0.0
#
# [103422 rows x 9 columns]

# %% [markdown]
# ### Making new updated csv file after encoding

# %%
df.to_csv('updated_cust_satisfaction_csv')
