# %%
import numpy as np
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns #advanced version of matplot lib

# %%
data = sns.load_dataset("tips") #built-in sample dataset provided by Seaborn

# %% [markdown]
# > other built-in data sets are:
# ```
# sns.load_dataset("iris")
# sns.load_dataset("titanic")```

# %%
data #data of a restaurant from seaborn module
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
plt.plot(data["total_bill"]) # Plot total_bill values against dataset index

# %% [markdown]
# ##### ``` plt.plot()``` creates basic line plots, while ```sns.lineplot()``` adds statistical features and better styling

# %%
sns.lineplot(data["total_bill"]) 
#sns.lineplot(x=data.index, y=data["total_bill"])

plt.show()

# %%
sns.barplot(x=data["tip"], y=data["total_bill"]) #bar graph showing average total_bill for each category
# Out:
# <Axes: xlabel='tip', ylabel='total_bill'>

# %%
sns.scatterplot(data["total_bill"]) #scatter graph
plt.show()

# %%
sns.scatterplot(x="total_bill",y="tip",data =data)
#sns.scatterplot(x=data["total_bill"],y=data["tip"])
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ##### above graph shows that between price range 10-20, customers giving maximum tip , its called data visualisation here ,

# %%
sns.histplot(data["total_bill"]) #histogram
# Out:
# <Axes: xlabel='total_bill', ylabel='Count'>

# %% [markdown]
# >KDE plot
# - kdeplot = Kernel Density Estimation
# - It shows the distribution of total_bill
# - This is a smooth probability density curve, not bars

# %%
sns.kdeplot(data["total_bill"])
# Out:
# <Axes: xlabel='total_bill', ylabel='Density'>

# %% [markdown]
# ##### ```scatterplot()``` draws a single plot on one axes, while ```relplot() ```creates a figure that can contain multiple relational plots using subplots.

# %%
sns.relplot(x="total_bill",y="tip",data=data) #RELATION PLOT
plt.show()

# %%
sns.relplot(x="total_bill",y="tip",data=data,hue="time")
# hue is used to differentiate data points using colors based on a categorical variable
plt.show()

# %%
sns.relplot(x="total_bill",y="tip",data=data,hue="sex")
plt.show()

# %%
sns.relplot(x="total_bill",y="tip",data=data,hue="smoker")
plt.show()

# %%
sns.relplot(x="total_bill",y="tip",data=data,hue="time",style="smoker")
# style differentiates data points using different marker shapes based on a category
plt.show()

# %%
sns.relplot(x="total_bill",y="tip",data=data,hue="time",style="smoker",row="day")
# row creates separate subplots in vertical rows based on a categorical variable
plt.show()

# %%
sns.relplot(x="total_bill",y="tip",data=data,hue="time",style="smoker",col="day")
# col creates separate subplots arranged in columns for each category
plt.show() #rest three days are vacation

# %%
sns.relplot(x="total_bill",y="tip",data=data,hue="time")
plt.xlabel('total_bill') #labelling
plt.ylabel('tip')
plt.title("hm seaborn pdh rhe hai") #title of graph
plt.show()

# %% [markdown]
# - ```relplot()``` → relation (numeric vs numeric)
#
# - ```catplot()``` → categories (category vs number)

# %%
sns.catplot(x="day",y="total_bill",data=data) #cat plot
# creates a strip plot showing individual data points per category

# %%
sns.catplot(x="day", data=data, kind="count") # How many records per day

# %%
sns.catplot(x="day",y="total_bill",data=data,kind="bar") # Bar catplot shows the mean total_bill for each day category

# %%
sns.catplot(x="day",y="total_bill",data=data,kind="box") # Box catplot shows the distribution, median, and outliers of total_bill for each day

# %%
sns.catplot(x="day",y="total_bill",data=data,kind="boxen")
# Boxen plot shows a more detailed distribution than a box plot using multiple quantiles

# %%
sns.catplot(x="day",y="total_bill",data=data,kind="swarm")
# Swarm plot avoids overlapping points, unlike the default strip plot

# %%
sns.catplot(x="day",y="total_bill",data=data,kind="strip") #default cat plot

# %%
sns.catplot(x="day",y="total_bill",data=data,kind="point")
# Point plot displays mean values for each category using points and connecting lines

# %%
sns.regplot(x="total_bill", y="tip", data=data)
# regplot shows the relationship between two variables with a regression line
# Out:
# <Axes: xlabel='total_bill', ylabel='tip'>

# %% [markdown]
# ##### Scatterplot shows data, regplot shows data + trend

# %% [markdown]
# >HEAT MAP (extra)

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np

# Load dataset
data = sns.load_dataset("tips")

# Compute correlation matrix (numeric columns only)
corr = data.corr(numeric_only=True)

# Create identity mask
mask = np.eye(corr.shape[0], dtype=bool)

# Plot heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(
    corr,
    mask=mask,
    annot=True,
    cmap="coolwarm",
    fmt=".2f"
)

plt.title("Correlation Heatmap (Diagonal Masked)")
plt.show()
